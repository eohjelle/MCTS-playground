# %%
# Change directory to the root of the project
import os 
os.chdir('..')
print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: /Users/eohjelle/Documents/2025-dots-and-boxes/dots-and-boxes

# %% [markdown]
# In this notebook we will do single runs for experimental transformer based models using training data generated with a Minimax model. This is based on tic_tac_toe_transformer_single_run.ipynb.

# %%
# Load the training data

from core.data_structures import ReplayBuffer
import random
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")

buffer = ReplayBuffer.from_wandb(
    project='AlphaZero-TicTacToe',
    artifact_name='tic_tac_toe_transformer_training_data',
    artifact_version='latest',
    device=device
)

print(f"Buffer size: {buffer.states.shape[0]}")
for i in random.sample(range(buffer.states.shape[0]), 1):
    print(f"Buffer state {i}: {buffer.states[i]}")
    for key in buffer.targets.keys():
        print(f"Buffer target {key} {i}: {buffer.targets[key][i]}")
    for key in buffer.data.keys():
        print(f"Buffer data {key} {i}: {buffer.data[key][i]}")
# Out:
# wandb:   1 of 1 files downloaded.
# /Users/eohjelle/Documents/2025-dots-and-boxes/dots-and-boxes/core/data_structures.py:94: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location=device)
# Buffer size: 5478
# Buffer state 1875: tensor([1, 2, 2, 1, 2, 0, 0, 0, 0], device='mps:0')
# Buffer target policy 1875: tensor([0., 0., 0., 0., 0., 0., 1., 0., 0.], device='mps:0')
# Buffer target value 1875: 1.0
# Buffer data legal_actions 1875: tensor([0., 0., 0., 0., 0., 1., 1., 1., 1.], device='mps:0')

# %%
from applications.tic_tac_toe.game_state import TicTacToeState
from core.implementations.Minimax import Minimax

# Creat minmax agent and expand the game tree, this will be used for evaluation later on
state = TicTacToeState()
minimax_agent = Minimax(state)
minimax_agent_root = minimax_agent.root
minimax_agent()

def minimax_agent_factory() -> Minimax:
    """
    This function returns a minimax agent that is initialized with the root of the game tree.
    """
    minimax_agent.root = minimax_agent_root
    return minimax_agent

# %%
# Define config

model_type = 'experimental_transformer'

config = {
    # Optimizer parameters
    'learning_rate': 0.01,
    'weight_decay': 0.0001,

    # Learning rate scheduler parameters
    'lr_scheduler': 'plateau',  # Options: 'step', 'multistep', 'exponential', 'cosine', 'plateau'
    # 'lr_eta_min': 1e-6, # For CosineAnnealingLR
    # 'lr_step_size': 30,  # For StepLR
    'lr_gamma': 0.5,  # For StepLR, MultiStepLR, ExponentialLR, ReduceLROnPlateau
    # 'lr_milestones': [30, 60, 90],  # For MultiStepLR
    # 'lr_t_max': 1000,  # For CosineAnnealingLR (usually set to total epochs)
    'lr_patience': 25,  # For ReduceLROnPlateau
    'lr_cooldown': 50,  # For ReduceLROnPlateau

    # Model parameters
    'embed_dim': 32,
    'num_heads': 4,

    # Training parameters
    'epochs': 500,
    'batch_size': 256,
    'mask_illegal_moves': False,
    'mask_value': -10.0,
    'eval_freq': 50
}

# %%
# Define simple training loop

import wandb
from applications.tic_tac_toe import TicTacToeState, TokenizedTensorMapping, TicTacToeExperimentalTransformer, ExperimentalTransformerInitParams
import torch
import torch.nn.functional as F
import numpy as np
from torch.utils.data import DataLoader, TensorDataset, random_split
from core import benchmark, ModelInterface
from core.implementations.RandomAgent import RandomAgent
from core.implementations.AlphaZero import AlphaZeroModelAgent

def baseline_best_loss():
    api = wandb.Api()
    artifact = api.artifact(f'AlphaZero-TicTacToe/{model_type}_model:latest')
    return artifact.metadata['loss']
    

def do_run(run):
    config = run.config
    model_interface = ModelInterface(
        model_architecture=TicTacToeExperimentalTransformer,
        init_params=ExperimentalTransformerInitParams(
            embed_dim=config.embed_dim,
            num_heads=config.num_heads
        ),
        device=device
    )
    model = model_interface.model

    wandb.watch(
        models=model,
        log="all",
        log_freq=20,
        log_graph=True
    )
    
    # Create optimizer
    optimizer = torch.optim.Adam(
        model.parameters(), 
        lr=config.learning_rate,
        weight_decay=config.weight_decay
    )

    # Create learning rate scheduler
    match config['lr_scheduler']:
        case 'step':
            scheduler = torch.optim.lr_scheduler.StepLR(
                optimizer, 
                step_size=config['lr_step_size'], 
                gamma=config['lr_gamma']
            )
        case 'multistep':
            scheduler = torch.optim.lr_scheduler.MultiStepLR(
                optimizer, 
                milestones=config['lr_milestones'], 
                gamma=config['lr_gamma']
            )
        case 'exponential':
            scheduler = torch.optim.lr_scheduler.ExponentialLR(
                optimizer, 
                gamma=config['lr_gamma']
                )
        case 'cosine':
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, 
                T_max=config['lr_t_max'],
                eta_min=1e-6
            )
        case 'plateau':
            scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, 
                mode='min', 
                factor=config['lr_gamma'], 
                patience=config['lr_patience'],
                cooldown=config['lr_cooldown']
            )
        case _:
            scheduler = None

    print(f"Using learning rate scheduler: {config['lr_scheduler']}")
    
    # Create datasets
    states = buffer.states
    policy_targets = buffer.targets['policy']
    value_targets = buffer.targets['value']
    legal_actions_mask = buffer.data['legal_actions']
    
    # Create dataset and split into train/val
    dataset = TensorDataset(states, policy_targets, value_targets, legal_actions_mask)
    train_size = int(0.9 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=config.batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config.batch_size, shuffle=False)
    
    # Initialize best validation loss
    try:
        best_val_loss = float(baseline_best_loss())
    except Exception as e:
        print(f"Error getting baseline best loss: {e}")
        best_val_loss = float('inf')
    
    # Training loop
    for epoch in range(1, config.epochs + 1):
        # Training phase
        model.train()
        train_losses = []
        policy_losses = []
        value_losses = []
        
        for batch in train_loader:
            states_batch, policy_targets_batch, value_targets_batch, legal_actions_batch = batch
            
            # Zero gradients
            optimizer.zero_grad()
            
            # Forward pass
            outputs = model(states_batch)
            policy_logits = outputs['policy']
            value_pred = outputs['value']
            
            # Apply mask for illegal moves if enabled
            if config.mask_illegal_moves:
                policy_logits = policy_logits * legal_actions_batch + (1 - legal_actions_batch) * config.mask_value
            
            # Compute losses
            policy_loss = F.cross_entropy(policy_logits, policy_targets_batch)
            value_loss = F.mse_loss(value_pred, value_targets_batch)
            total_loss = policy_loss + value_loss
            
            # Backward pass and optimization
            total_loss.backward()
            optimizer.step()
            
            # Track metrics
            train_losses.append(total_loss.item())
            policy_losses.append(policy_loss.item())
            value_losses.append(value_loss.item())
        
        # Validation phase
        model.eval()
        val_losses = []
        val_policy_losses = []
        val_value_losses = []
        
        with torch.no_grad():
            for batch in val_loader:
                states_batch, policy_targets_batch, value_targets_batch, legal_actions_batch = batch
                
                # Forward pass
                outputs = model(states_batch)
                policy_logits = outputs['policy']
                value_pred = outputs['value']
                
                # Apply mask for illegal moves if enabled
                if config.mask_illegal_moves:
                    policy_logits = policy_logits * legal_actions_batch + (1 - legal_actions_batch) * config.mask_value
                
                # Compute losses
                policy_loss = F.cross_entropy(policy_logits, policy_targets_batch)
                value_loss = F.mse_loss(value_pred, value_targets_batch)
                total_loss = policy_loss + value_loss
                
                # Track metrics
                val_losses.append(total_loss.item())
                val_policy_losses.append(policy_loss.item())
                val_value_losses.append(value_loss.item())
        
        # Calculate average metrics
        avg_train_loss = np.mean(train_losses)
        avg_val_loss = np.mean(val_losses)
        
        current_lr = optimizer.param_groups[0]['lr']

        # Log metrics to wandb
        wandb.log({
            "epoch": epoch,
            "train_loss": avg_train_loss,
            "train_policy_loss": np.mean(policy_losses),
            "train_value_loss": np.mean(value_losses),
            "val_loss": avg_val_loss,
            "val_policy_loss": np.mean(val_policy_losses),
            "val_value_loss": np.mean(val_value_losses),
            "learning_rate": current_lr
        }, step=epoch)
        
        print(f"Epoch {epoch}/{config.epochs}, "
                f"Train Loss: {avg_train_loss:.4f}, "
                f"Val Loss: {avg_val_loss:.4f}, "
                f"Learning rate: {current_lr:.6f}")
        
        # Update the learning rate scheduler
        if scheduler is not None:

            # Update scheduler based on its actual type
            if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                scheduler.step(avg_train_loss)  # ReduceLROnPlateau needs a metric
            else:
                scheduler.step()  # All other schedulers just need step()
    
        
        # Save best model
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            
            # Save model checkpoint
            if not os.path.exists('checkpoints'):
                os.makedirs('checkpoints')
                
            checkpoint_path = f"checkpoints/tic_tac_toe_{model_type}_best_model.pt"
            metadata = {
                'loss': best_val_loss
            }
            model_interface.save_checkpoint(
                checkpoint_path,
                metadata=metadata
            )
            model_interface.save_to_wandb(
                model_name=f'{model_type}_model',
                wandb_run=run,
                project='AlphaZero-TicTacToe',
                description=f'Best model with val_loss: {best_val_loss:.4f}',
                metadata=metadata
            )

        # Evaluate against agents
        if epoch % config.eval_freq == 0 or epoch == config.epochs - 1:
            stats = benchmark(
                create_agent=lambda state: AlphaZeroModelAgent(
                    initial_state=state,
                    model=model_interface,
                    tensor_mapping=TokenizedTensorMapping(),
                    temperature=0.0
                ),
                create_opponents={
                    'random': lambda state: RandomAgent(state),
                    'minimax': lambda state: minimax_agent_factory()
                },
                initial_state=lambda: TicTacToeState(),
                num_games=100
            )
            print(f"RandomAgent score: {stats['random']['win_rate'] - stats['random']['loss_rate']}")
            print(f"Minimax draw rate: {stats['minimax']['draw_rate']}")
            wandb.log({
                'random_win_rate': stats['random']['win_rate'],
                'minimax_win_rate': stats['minimax']['win_rate'],
                'random_draw_rate': stats['random']['draw_rate'],
                'minimax_draw_rate': stats['minimax']['draw_rate'],
                'random_loss_rate': stats['random']['loss_rate'],
                'minimax_loss_rate': stats['minimax']['loss_rate'],
                'random_score': stats['random']['win_rate'] - stats['random']['loss_rate'],
                'minimax_score': stats['minimax']['win_rate'] - stats['minimax']['loss_rate']
            }, step=epoch)

# %%
run = wandb.init(
    project="AlphaZero-TicTacToe",
    id=None,
    config=config
)
do_run(run)
# Out:
# wandb: Currently logged in as: eohjelle (eigenway) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/Users/eohjelle/Documents/2025-dots-and-boxes/dots-and-boxes/wandb/run-20250314_092348-5ifssm24</code>
# Syncing run <strong><a href='https://wandb.ai/eigenway/AlphaZero-TicTacToe/runs/5ifssm24' target="_blank">peach-flan-221</a></strong> to <a href='https://wandb.ai/eigenway/AlphaZero-TicTacToe' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/eigenway/AlphaZero-TicTacToe' target="_blank">https://wandb.ai/eigenway/AlphaZero-TicTacToe</a>
#  View run at <a href='https://wandb.ai/eigenway/AlphaZero-TicTacToe/runs/5ifssm24' target="_blank">https://wandb.ai/eigenway/AlphaZero-TicTacToe/runs/5ifssm24</a>
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# Using learning rate scheduler: plateau
# Error getting baseline best loss: artifact 'experimental_transformer_model:latest' not found in 'eigenway/AlphaZero-TicTacToe'
# Epoch 1/500, Train Loss: 2.5027, Val Loss: 2.3234, Learning rate: 0.010000
# Epoch 2/500, Train Loss: 2.0830, Val Loss: 2.0016, Learning rate: 0.010000
# Epoch 3/500, Train Loss: 1.7937, Val Loss: 1.7273, Learning rate: 0.010000
# Epoch 4/500, Train Loss: 1.6428, Val Loss: 1.5910, Learning rate: 0.010000
# Epoch 5/500, Train Loss: 1.5777, Val Loss: 1.5743, Learning rate: 0.010000
# Epoch 6/500, Train Loss: 1.5623, Val Loss: 1.6192, Learning rate: 0.010000
# Epoch 7/500, Train Loss: 1.5725, Val Loss: 1.5741, Learning rate: 0.010000
# Epoch 8/500, Train Loss: 1.5458, Val Loss: 1.5590, Learning rate: 0.010000
# Epoch 9/500, Train Loss: 1.5455, Val Loss: 1.5393, Learning rate: 0.010000
# Epoch 10/500, Train Loss: 1.5309, Val Loss: 1.5368, Learning rate: 0.010000
# Epoch 11/500, Train Loss: 1.5203, Val Loss: 1.5396, Learning rate: 0.010000
# Epoch 12/500, Train Loss: 1.5001, Val Loss: 1.5128, Learning rate: 0.010000
# Epoch 13/500, Train Loss: 1.4811, Val Loss: 1.4764, Learning rate: 0.010000
# Epoch 14/500, Train Loss: 1.4362, Val Loss: 1.3672, Learning rate: 0.010000
# Epoch 15/500, Train Loss: 1.3366, Val Loss: 1.2551, Learning rate: 0.010000
# Epoch 16/500, Train Loss: 1.2566, Val Loss: 1.2841, Learning rate: 0.010000
# Epoch 17/500, Train Loss: 1.2062, Val Loss: 1.1708, Learning rate: 0.010000
# Epoch 18/500, Train Loss: 1.1442, Val Loss: 1.0943, Learning rate: 0.010000
# Epoch 19/500, Train Loss: 1.0935, Val Loss: 1.0456, Learning rate: 0.010000
# Epoch 20/500, Train Loss: 1.0554, Val Loss: 1.0253, Learning rate: 0.010000
# Epoch 21/500, Train Loss: 1.0076, Val Loss: 1.0160, Learning rate: 0.010000
# Epoch 22/500, Train Loss: 0.9730, Val Loss: 0.9737, Learning rate: 0.010000
# Epoch 23/500, Train Loss: 0.9407, Val Loss: 0.9489, Learning rate: 0.010000
# Epoch 24/500, Train Loss: 0.9222, Val Loss: 0.9220, Learning rate: 0.010000
# Epoch 25/500, Train Loss: 0.9158, Val Loss: 0.9145, Learning rate: 0.010000
# Epoch 26/500, Train Loss: 0.9052, Val Loss: 0.9035, Learning rate: 0.010000
# Epoch 27/500, Train Loss: 0.8880, Val Loss: 0.9476, Learning rate: 0.010000
# Epoch 28/500, Train Loss: 0.8739, Val Loss: 0.9599, Learning rate: 0.010000
# Epoch 29/500, Train Loss: 0.8745, Val Loss: 0.8936, Learning rate: 0.010000
# Epoch 30/500, Train Loss: 0.8583, Val Loss: 0.8557, Learning rate: 0.010000
# Epoch 31/500, Train Loss: 0.8459, Val Loss: 0.8767, Learning rate: 0.010000
# Epoch 32/500, Train Loss: 0.8574, Val Loss: 0.8769, Learning rate: 0.010000
# Epoch 33/500, Train Loss: 0.8238, Val Loss: 0.8465, Learning rate: 0.010000
# Epoch 34/500, Train Loss: 0.8083, Val Loss: 0.8346, Learning rate: 0.010000
# Epoch 35/500, Train Loss: 0.8178, Val Loss: 0.8281, Learning rate: 0.010000
# Epoch 36/500, Train Loss: 0.8145, Val Loss: 0.8222, Learning rate: 0.010000
# Epoch 37/500, Train Loss: 0.8091, Val Loss: 0.8247, Learning rate: 0.010000
# Epoch 38/500, Train Loss: 0.7971, Val Loss: 0.8277, Learning rate: 0.010000
# Epoch 39/500, Train Loss: 0.7914, Val Loss: 0.8132, Learning rate: 0.010000
# Epoch 40/500, Train Loss: 0.7743, Val Loss: 0.8398, Learning rate: 0.010000
# Epoch 41/500, Train Loss: 0.7712, Val Loss: 0.7755, Learning rate: 0.010000
# Epoch 42/500, Train Loss: 0.7864, Val Loss: 0.8328, Learning rate: 0.010000
# Epoch 43/500, Train Loss: 0.7844, Val Loss: 0.8256, Learning rate: 0.010000
# Epoch 44/500, Train Loss: 0.7666, Val Loss: 0.7844, Learning rate: 0.010000
# Epoch 45/500, Train Loss: 0.7671, Val Loss: 0.8167, Learning rate: 0.010000
# Epoch 46/500, Train Loss: 0.7656, Val Loss: 0.7644, Learning rate: 0.010000
# Epoch 47/500, Train Loss: 0.7614, Val Loss: 0.7929, Learning rate: 0.010000
# Epoch 48/500, Train Loss: 0.7541, Val Loss: 0.7848, Learning rate: 0.010000
# Epoch 49/500, Train Loss: 0.7425, Val Loss: 0.7942, Learning rate: 0.010000
# Epoch 50/500, Train Loss: 0.7408, Val Loss: 0.7536, Learning rate: 0.010000
# RandomAgent score: 0.9
# Minimax draw rate: 0.93
# Epoch 51/500, Train Loss: 0.7499, Val Loss: 0.8003, Learning rate: 0.010000
# Epoch 52/500, Train Loss: 0.7395, Val Loss: 0.7778, Learning rate: 0.010000
# Epoch 53/500, Train Loss: 0.7357, Val Loss: 0.7888, Learning rate: 0.010000
# Epoch 54/500, Train Loss: 0.7432, Val Loss: 0.7980, Learning rate: 0.010000
# Epoch 55/500, Train Loss: 0.7391, Val Loss: 0.8009, Learning rate: 0.010000
# Epoch 56/500, Train Loss: 0.7290, Val Loss: 0.7864, Learning rate: 0.010000
# Epoch 57/500, Train Loss: 0.7366, Val Loss: 0.8028, Learning rate: 0.010000
# Epoch 58/500, Train Loss: 0.7325, Val Loss: 0.7868, Learning rate: 0.010000
# Epoch 59/500, Train Loss: 0.7283, Val Loss: 0.7903, Learning rate: 0.010000
# Epoch 60/500, Train Loss: 0.7178, Val Loss: 0.7799, Learning rate: 0.010000
# Epoch 61/500, Train Loss: 0.7244, Val Loss: 0.7795, Learning rate: 0.010000
# Epoch 62/500, Train Loss: 0.7233, Val Loss: 0.7886, Learning rate: 0.010000
# Epoch 63/500, Train Loss: 0.7145, Val Loss: 0.7778, Learning rate: 0.010000
# Epoch 64/500, Train Loss: 0.7159, Val Loss: 0.7909, Learning rate: 0.010000
# Epoch 65/500, Train Loss: 0.7138, Val Loss: 0.8090, Learning rate: 0.010000
# Epoch 66/500, Train Loss: 0.7139, Val Loss: 0.7692, Learning rate: 0.010000
# Epoch 67/500, Train Loss: 0.7010, Val Loss: 0.7618, Learning rate: 0.010000
# Epoch 68/500, Train Loss: 0.6970, Val Loss: 0.7836, Learning rate: 0.010000
# Epoch 69/500, Train Loss: 0.7170, Val Loss: 0.7804, Learning rate: 0.010000
# Epoch 70/500, Train Loss: 0.7137, Val Loss: 0.8005, Learning rate: 0.010000
# Epoch 71/500, Train Loss: 0.7139, Val Loss: 0.8100, Learning rate: 0.010000
# Epoch 72/500, Train Loss: 0.6925, Val Loss: 0.7741, Learning rate: 0.005000
# Epoch 73/500, Train Loss: 0.6787, Val Loss: 0.7699, Learning rate: 0.005000
# Epoch 74/500, Train Loss: 0.6758, Val Loss: 0.7727, Learning rate: 0.005000
# Epoch 75/500, Train Loss: 0.6724, Val Loss: 0.7615, Learning rate: 0.005000
# Epoch 76/500, Train Loss: 0.6720, Val Loss: 0.7659, Learning rate: 0.005000
# Epoch 77/500, Train Loss: 0.6680, Val Loss: 0.7630, Learning rate: 0.005000
# Epoch 78/500, Train Loss: 0.6705, Val Loss: 0.7659, Learning rate: 0.005000
# Epoch 79/500, Train Loss: 0.6690, Val Loss: 0.7813, Learning rate: 0.005000
# Epoch 80/500, Train Loss: 0.6683, Val Loss: 0.7710, Learning rate: 0.005000
# Epoch 81/500, Train Loss: 0.6761, Val Loss: 0.7690, Learning rate: 0.005000
# Epoch 82/500, Train Loss: 0.6729, Val Loss: 0.7481, Learning rate: 0.005000
# Epoch 83/500, Train Loss: 0.6643, Val Loss: 0.7691, Learning rate: 0.005000
# Epoch 84/500, Train Loss: 0.6727, Val Loss: 0.7581, Learning rate: 0.005000
# Epoch 85/500, Train Loss: 0.6653, Val Loss: 0.7627, Learning rate: 0.005000
# Epoch 86/500, Train Loss: 0.6607, Val Loss: 0.7663, Learning rate: 0.005000
# Epoch 87/500, Train Loss: 0.6620, Val Loss: 0.7678, Learning rate: 0.005000
# Epoch 88/500, Train Loss: 0.6688, Val Loss: 0.7586, Learning rate: 0.005000
# Epoch 89/500, Train Loss: 0.6632, Val Loss: 0.7610, Learning rate: 0.005000
# Epoch 90/500, Train Loss: 0.6657, Val Loss: 0.7598, Learning rate: 0.005000
# Epoch 91/500, Train Loss: 0.6569, Val Loss: 0.7625, Learning rate: 0.005000
# Epoch 92/500, Train Loss: 0.6650, Val Loss: 0.7636, Learning rate: 0.005000
# Epoch 93/500, Train Loss: 0.6676, Val Loss: 0.7667, Learning rate: 0.005000
# Epoch 94/500, Train Loss: 0.6582, Val Loss: 0.7574, Learning rate: 0.005000
# Epoch 95/500, Train Loss: 0.6582, Val Loss: 0.7616, Learning rate: 0.005000
# Epoch 96/500, Train Loss: 0.6626, Val Loss: 0.7581, Learning rate: 0.005000
# Epoch 97/500, Train Loss: 0.6643, Val Loss: 0.7843, Learning rate: 0.005000
# Epoch 98/500, Train Loss: 0.6686, Val Loss: 0.7612, Learning rate: 0.005000
# Epoch 99/500, Train Loss: 0.6634, Val Loss: 0.7714, Learning rate: 0.005000
# Epoch 100/500, Train Loss: 0.6555, Val Loss: 0.7788, Learning rate: 0.005000
# RandomAgent score: 0.98
# Minimax draw rate: 0.98
# Epoch 101/500, Train Loss: 0.6589, Val Loss: 0.7703, Learning rate: 0.005000
# Epoch 102/500, Train Loss: 0.6633, Val Loss: 0.7643, Learning rate: 0.005000
# Epoch 103/500, Train Loss: 0.6542, Val Loss: 0.7582, Learning rate: 0.005000
# Epoch 104/500, Train Loss: 0.6484, Val Loss: 0.7637, Learning rate: 0.005000
# Epoch 105/500, Train Loss: 0.6612, Val Loss: 0.7613, Learning rate: 0.005000
# Epoch 106/500, Train Loss: 0.6617, Val Loss: 0.7729, Learning rate: 0.005000
# Epoch 107/500, Train Loss: 0.6557, Val Loss: 0.7602, Learning rate: 0.005000
# Epoch 108/500, Train Loss: 0.6559, Val Loss: 0.7662, Learning rate: 0.005000
# Epoch 109/500, Train Loss: 0.6558, Val Loss: 0.7709, Learning rate: 0.005000
# Epoch 110/500, Train Loss: 0.6550, Val Loss: 0.7665, Learning rate: 0.005000
# Epoch 111/500, Train Loss: 0.6527, Val Loss: 0.7626, Learning rate: 0.005000
# Epoch 112/500, Train Loss: 0.6574, Val Loss: 0.7759, Learning rate: 0.005000
# Epoch 113/500, Train Loss: 0.6580, Val Loss: 0.7715, Learning rate: 0.005000
# Epoch 114/500, Train Loss: 0.6615, Val Loss: 0.7770, Learning rate: 0.005000
# Epoch 115/500, Train Loss: 0.6534, Val Loss: 0.7672, Learning rate: 0.005000
# Epoch 116/500, Train Loss: 0.6591, Val Loss: 0.7583, Learning rate: 0.005000
# Epoch 117/500, Train Loss: 0.6557, Val Loss: 0.7668, Learning rate: 0.005000
# Epoch 118/500, Train Loss: 0.6502, Val Loss: 0.7671, Learning rate: 0.005000
# Epoch 119/500, Train Loss: 0.6479, Val Loss: 0.7550, Learning rate: 0.005000
# Epoch 120/500, Train Loss: 0.6560, Val Loss: 0.7626, Learning rate: 0.005000
# Epoch 121/500, Train Loss: 0.6491, Val Loss: 0.7674, Learning rate: 0.005000
# Epoch 122/500, Train Loss: 0.6520, Val Loss: 0.7760, Learning rate: 0.005000
# Epoch 123/500, Train Loss: 0.6546, Val Loss: 0.7719, Learning rate: 0.005000
# Epoch 124/500, Train Loss: 0.6578, Val Loss: 0.7756, Learning rate: 0.005000
# Epoch 125/500, Train Loss: 0.6537, Val Loss: 0.7700, Learning rate: 0.005000
# Epoch 126/500, Train Loss: 0.6550, Val Loss: 0.7759, Learning rate: 0.005000
# Epoch 127/500, Train Loss: 0.6376, Val Loss: 0.7655, Learning rate: 0.005000
# Epoch 128/500, Train Loss: 0.6448, Val Loss: 0.7573, Learning rate: 0.005000
# Epoch 129/500, Train Loss: 0.6491, Val Loss: 0.7557, Learning rate: 0.005000
# Epoch 130/500, Train Loss: 0.6464, Val Loss: 0.7603, Learning rate: 0.005000
# Epoch 131/500, Train Loss: 0.6457, Val Loss: 0.7648, Learning rate: 0.005000
# Epoch 132/500, Train Loss: 0.6528, Val Loss: 0.7520, Learning rate: 0.005000
# Epoch 133/500, Train Loss: 0.6495, Val Loss: 0.7651, Learning rate: 0.005000
# Epoch 134/500, Train Loss: 0.6428, Val Loss: 0.7526, Learning rate: 0.005000
# Epoch 135/500, Train Loss: 0.6481, Val Loss: 0.7760, Learning rate: 0.005000
# Epoch 136/500, Train Loss: 0.6565, Val Loss: 0.7650, Learning rate: 0.005000
# Epoch 137/500, Train Loss: 0.6460, Val Loss: 0.7623, Learning rate: 0.005000
# Epoch 138/500, Train Loss: 0.6431, Val Loss: 0.7634, Learning rate: 0.005000
# Epoch 139/500, Train Loss: 0.6478, Val Loss: 0.7552, Learning rate: 0.005000
# Epoch 140/500, Train Loss: 0.6396, Val Loss: 0.7605, Learning rate: 0.005000
# Epoch 141/500, Train Loss: 0.6422, Val Loss: 0.7624, Learning rate: 0.005000
# Epoch 142/500, Train Loss: 0.6415, Val Loss: 0.7692, Learning rate: 0.005000
# Epoch 143/500, Train Loss: 0.6415, Val Loss: 0.7672, Learning rate: 0.005000
# Epoch 144/500, Train Loss: 0.6432, Val Loss: 0.7735, Learning rate: 0.005000
# Epoch 145/500, Train Loss: 0.6441, Val Loss: 0.7767, Learning rate: 0.005000
# Epoch 146/500, Train Loss: 0.6512, Val Loss: 0.7653, Learning rate: 0.005000
# Epoch 147/500, Train Loss: 0.6436, Val Loss: 0.7710, Learning rate: 0.005000
# Epoch 148/500, Train Loss: 0.6435, Val Loss: 0.7577, Learning rate: 0.005000
# Epoch 149/500, Train Loss: 0.6485, Val Loss: 0.7585, Learning rate: 0.005000
# Epoch 150/500, Train Loss: 0.6436, Val Loss: 0.7731, Learning rate: 0.005000
# RandomAgent score: 0.93
# Minimax draw rate: 0.97
# Epoch 151/500, Train Loss: 0.6421, Val Loss: 0.7701, Learning rate: 0.005000
# Epoch 152/500, Train Loss: 0.6452, Val Loss: 0.7709, Learning rate: 0.005000
# Epoch 153/500, Train Loss: 0.6541, Val Loss: 0.7620, Learning rate: 0.005000
# Epoch 154/500, Train Loss: 0.6447, Val Loss: 0.7577, Learning rate: 0.005000
# Epoch 155/500, Train Loss: 0.6394, Val Loss: 0.7692, Learning rate: 0.005000
# Epoch 156/500, Train Loss: 0.6468, Val Loss: 0.7712, Learning rate: 0.005000
# Epoch 157/500, Train Loss: 0.6416, Val Loss: 0.7695, Learning rate: 0.005000
# Epoch 158/500, Train Loss: 0.6514, Val Loss: 0.7814, Learning rate: 0.005000
# Epoch 159/500, Train Loss: 0.6482, Val Loss: 0.7656, Learning rate: 0.005000
# Epoch 160/500, Train Loss: 0.6415, Val Loss: 0.7861, Learning rate: 0.005000
# Epoch 161/500, Train Loss: 0.6450, Val Loss: 0.7625, Learning rate: 0.005000
# Epoch 162/500, Train Loss: 0.6567, Val Loss: 0.7841, Learning rate: 0.005000
# Epoch 163/500, Train Loss: 0.6513, Val Loss: 0.7738, Learning rate: 0.005000
# Epoch 164/500, Train Loss: 0.6431, Val Loss: 0.7604, Learning rate: 0.005000
# Epoch 165/500, Train Loss: 0.6485, Val Loss: 0.7591, Learning rate: 0.005000
# Epoch 166/500, Train Loss: 0.6488, Val Loss: 0.7696, Learning rate: 0.005000
# Epoch 167/500, Train Loss: 0.6343, Val Loss: 0.7595, Learning rate: 0.005000
# Epoch 168/500, Train Loss: 0.6377, Val Loss: 0.7688, Learning rate: 0.005000
# Epoch 169/500, Train Loss: 0.6390, Val Loss: 0.7530, Learning rate: 0.005000
# Epoch 170/500, Train Loss: 0.6398, Val Loss: 0.7874, Learning rate: 0.005000
# Epoch 171/500, Train Loss: 0.6456, Val Loss: 0.7683, Learning rate: 0.005000
# Epoch 172/500, Train Loss: 0.6370, Val Loss: 0.7670, Learning rate: 0.005000
# Epoch 173/500, Train Loss: 0.6349, Val Loss: 0.7796, Learning rate: 0.005000
# Epoch 174/500, Train Loss: 0.6466, Val Loss: 0.7612, Learning rate: 0.005000
# Epoch 175/500, Train Loss: 0.6432, Val Loss: 0.7711, Learning rate: 0.005000
# Epoch 176/500, Train Loss: 0.6401, Val Loss: 0.7722, Learning rate: 0.005000
# Epoch 177/500, Train Loss: 0.6385, Val Loss: 0.7531, Learning rate: 0.005000
# Epoch 178/500, Train Loss: 0.6326, Val Loss: 0.7598, Learning rate: 0.005000
# Epoch 179/500, Train Loss: 0.6211, Val Loss: 0.7832, Learning rate: 0.005000
# Epoch 180/500, Train Loss: 0.6350, Val Loss: 0.7659, Learning rate: 0.005000
# Epoch 181/500, Train Loss: 0.6283, Val Loss: 0.7687, Learning rate: 0.005000
# Epoch 182/500, Train Loss: 0.6363, Val Loss: 0.8021, Learning rate: 0.005000
# Epoch 183/500, Train Loss: 0.6377, Val Loss: 0.7651, Learning rate: 0.005000
# Epoch 184/500, Train Loss: 0.6358, Val Loss: 0.7649, Learning rate: 0.005000
# Epoch 185/500, Train Loss: 0.6320, Val Loss: 0.7671, Learning rate: 0.005000
# Epoch 186/500, Train Loss: 0.6325, Val Loss: 0.7700, Learning rate: 0.005000
# Epoch 187/500, Train Loss: 0.6316, Val Loss: 0.7585, Learning rate: 0.005000
# Epoch 188/500, Train Loss: 0.6313, Val Loss: 0.7623, Learning rate: 0.005000
# Epoch 189/500, Train Loss: 0.6281, Val Loss: 0.7642, Learning rate: 0.005000
# Epoch 190/500, Train Loss: 0.6294, Val Loss: 0.7573, Learning rate: 0.005000
# Epoch 191/500, Train Loss: 0.6297, Val Loss: 0.7819, Learning rate: 0.005000
# Epoch 192/500, Train Loss: 0.6299, Val Loss: 0.7725, Learning rate: 0.005000
# Epoch 193/500, Train Loss: 0.6239, Val Loss: 0.7594, Learning rate: 0.002500
# Epoch 194/500, Train Loss: 0.6157, Val Loss: 0.7568, Learning rate: 0.002500
# Epoch 195/500, Train Loss: 0.6137, Val Loss: 0.7538, Learning rate: 0.002500
# Epoch 196/500, Train Loss: 0.6120, Val Loss: 0.7585, Learning rate: 0.002500
# Epoch 197/500, Train Loss: 0.6099, Val Loss: 0.7530, Learning rate: 0.002500
# Epoch 198/500, Train Loss: 0.6159, Val Loss: 0.7612, Learning rate: 0.002500
# Epoch 199/500, Train Loss: 0.6167, Val Loss: 0.7592, Learning rate: 0.002500
# Epoch 200/500, Train Loss: 0.6159, Val Loss: 0.7633, Learning rate: 0.002500
# RandomAgent score: 0.94
# Minimax draw rate: 0.99
# Epoch 201/500, Train Loss: 0.6140, Val Loss: 0.7583, Learning rate: 0.002500
# Epoch 202/500, Train Loss: 0.6209, Val Loss: 0.7551, Learning rate: 0.002500
# Epoch 203/500, Train Loss: 0.6127, Val Loss: 0.7572, Learning rate: 0.002500
# Epoch 204/500, Train Loss: 0.6114, Val Loss: 0.7588, Learning rate: 0.002500
# Epoch 205/500, Train Loss: 0.6185, Val Loss: 0.7508, Learning rate: 0.002500
# Epoch 206/500, Train Loss: 0.6093, Val Loss: 0.7574, Learning rate: 0.002500
# Epoch 207/500, Train Loss: 0.6179, Val Loss: 0.7555, Learning rate: 0.002500
# Epoch 208/500, Train Loss: 0.6154, Val Loss: 0.7562, Learning rate: 0.002500
# Epoch 209/500, Train Loss: 0.6111, Val Loss: 0.7621, Learning rate: 0.002500
# Epoch 210/500, Train Loss: 0.6158, Val Loss: 0.7692, Learning rate: 0.002500
# Epoch 211/500, Train Loss: 0.6188, Val Loss: 0.7570, Learning rate: 0.002500
# Epoch 212/500, Train Loss: 0.6138, Val Loss: 0.7606, Learning rate: 0.002500
# Epoch 213/500, Train Loss: 0.6091, Val Loss: 0.7666, Learning rate: 0.002500
# Epoch 214/500, Train Loss: 0.6103, Val Loss: 0.7667, Learning rate: 0.002500
# Epoch 215/500, Train Loss: 0.6145, Val Loss: 0.7590, Learning rate: 0.002500
# Epoch 216/500, Train Loss: 0.6135, Val Loss: 0.7583, Learning rate: 0.002500
# Epoch 217/500, Train Loss: 0.6132, Val Loss: 0.7551, Learning rate: 0.002500
# Epoch 218/500, Train Loss: 0.6113, Val Loss: 0.7585, Learning rate: 0.002500
# Epoch 219/500, Train Loss: 0.6094, Val Loss: 0.7747, Learning rate: 0.002500
# Epoch 220/500, Train Loss: 0.6148, Val Loss: 0.7582, Learning rate: 0.002500
# Epoch 221/500, Train Loss: 0.6087, Val Loss: 0.7609, Learning rate: 0.002500
# Epoch 222/500, Train Loss: 0.6087, Val Loss: 0.7685, Learning rate: 0.002500
# Epoch 223/500, Train Loss: 0.6122, Val Loss: 0.7595, Learning rate: 0.002500
# Epoch 224/500, Train Loss: 0.6057, Val Loss: 0.7579, Learning rate: 0.002500
# Epoch 225/500, Train Loss: 0.6136, Val Loss: 0.7627, Learning rate: 0.002500
# Epoch 226/500, Train Loss: 0.6111, Val Loss: 0.7656, Learning rate: 0.002500
# Epoch 227/500, Train Loss: 0.6101, Val Loss: 0.7603, Learning rate: 0.002500
# Epoch 228/500, Train Loss: 0.6155, Val Loss: 0.7644, Learning rate: 0.002500
# Epoch 229/500, Train Loss: 0.6095, Val Loss: 0.7629, Learning rate: 0.002500
# Epoch 230/500, Train Loss: 0.6141, Val Loss: 0.7698, Learning rate: 0.002500
# Epoch 231/500, Train Loss: 0.6130, Val Loss: 0.7686, Learning rate: 0.002500
# Epoch 232/500, Train Loss: 0.6170, Val Loss: 0.7655, Learning rate: 0.002500
# Epoch 233/500, Train Loss: 0.6093, Val Loss: 0.7631, Learning rate: 0.002500
# Epoch 234/500, Train Loss: 0.6079, Val Loss: 0.7725, Learning rate: 0.002500
# Epoch 235/500, Train Loss: 0.6085, Val Loss: 0.7659, Learning rate: 0.002500
# Epoch 236/500, Train Loss: 0.6123, Val Loss: 0.7659, Learning rate: 0.002500
# Epoch 237/500, Train Loss: 0.6067, Val Loss: 0.7677, Learning rate: 0.002500
# Epoch 238/500, Train Loss: 0.6059, Val Loss: 0.7628, Learning rate: 0.002500
# Epoch 239/500, Train Loss: 0.6047, Val Loss: 0.7658, Learning rate: 0.002500
# Epoch 240/500, Train Loss: 0.6083, Val Loss: 0.7731, Learning rate: 0.002500
# Epoch 241/500, Train Loss: 0.6039, Val Loss: 0.7588, Learning rate: 0.002500
# Epoch 242/500, Train Loss: 0.6106, Val Loss: 0.7632, Learning rate: 0.002500
# Epoch 243/500, Train Loss: 0.6150, Val Loss: 0.7589, Learning rate: 0.002500
# Epoch 244/500, Train Loss: 0.6105, Val Loss: 0.7721, Learning rate: 0.002500
# Epoch 245/500, Train Loss: 0.6073, Val Loss: 0.7628, Learning rate: 0.002500
# Epoch 246/500, Train Loss: 0.6129, Val Loss: 0.7617, Learning rate: 0.002500
# Epoch 247/500, Train Loss: 0.6098, Val Loss: 0.7700, Learning rate: 0.002500
# Epoch 248/500, Train Loss: 0.6111, Val Loss: 0.7720, Learning rate: 0.002500
# Epoch 249/500, Train Loss: 0.6089, Val Loss: 0.7584, Learning rate: 0.002500
# Epoch 250/500, Train Loss: 0.6013, Val Loss: 0.7705, Learning rate: 0.002500
# RandomAgent score: 0.91
# Minimax draw rate: 1.0
# Epoch 251/500, Train Loss: 0.6117, Val Loss: 0.7694, Learning rate: 0.002500
# Epoch 252/500, Train Loss: 0.6103, Val Loss: 0.7744, Learning rate: 0.002500
# Epoch 253/500, Train Loss: 0.6133, Val Loss: 0.7690, Learning rate: 0.002500
# Epoch 254/500, Train Loss: 0.6059, Val Loss: 0.7722, Learning rate: 0.002500
# Epoch 255/500, Train Loss: 0.6082, Val Loss: 0.7573, Learning rate: 0.002500
# Epoch 256/500, Train Loss: 0.6061, Val Loss: 0.7606, Learning rate: 0.002500
# Epoch 257/500, Train Loss: 0.6091, Val Loss: 0.7790, Learning rate: 0.002500
# Epoch 258/500, Train Loss: 0.6121, Val Loss: 0.7633, Learning rate: 0.002500
# Epoch 259/500, Train Loss: 0.6102, Val Loss: 0.7666, Learning rate: 0.002500
# Epoch 260/500, Train Loss: 0.6099, Val Loss: 0.7668, Learning rate: 0.002500
# Epoch 261/500, Train Loss: 0.6087, Val Loss: 0.7606, Learning rate: 0.002500
# Epoch 262/500, Train Loss: 0.6078, Val Loss: 0.7655, Learning rate: 0.002500
# Epoch 263/500, Train Loss: 0.6100, Val Loss: 0.7651, Learning rate: 0.002500
# Epoch 264/500, Train Loss: 0.6128, Val Loss: 0.7573, Learning rate: 0.002500
# Epoch 265/500, Train Loss: 0.6055, Val Loss: 0.7596, Learning rate: 0.002500
# Epoch 266/500, Train Loss: 0.6096, Val Loss: 0.7796, Learning rate: 0.002500
# Epoch 267/500, Train Loss: 0.6177, Val Loss: 0.7696, Learning rate: 0.002500
# Epoch 268/500, Train Loss: 0.6100, Val Loss: 0.7621, Learning rate: 0.002500
# Epoch 269/500, Train Loss: 0.6070, Val Loss: 0.7650, Learning rate: 0.002500
# Epoch 270/500, Train Loss: 0.6052, Val Loss: 0.7727, Learning rate: 0.002500
# Epoch 271/500, Train Loss: 0.6091, Val Loss: 0.7726, Learning rate: 0.002500
# Epoch 272/500, Train Loss: 0.6016, Val Loss: 0.7606, Learning rate: 0.002500
# Epoch 273/500, Train Loss: 0.6112, Val Loss: 0.7717, Learning rate: 0.002500
# Epoch 274/500, Train Loss: 0.6068, Val Loss: 0.7664, Learning rate: 0.002500
# Epoch 275/500, Train Loss: 0.6016, Val Loss: 0.7644, Learning rate: 0.002500
# Epoch 276/500, Train Loss: 0.6022, Val Loss: 0.7634, Learning rate: 0.002500
# Epoch 277/500, Train Loss: 0.6052, Val Loss: 0.7737, Learning rate: 0.002500
# Epoch 278/500, Train Loss: 0.6056, Val Loss: 0.7601, Learning rate: 0.002500
# Epoch 279/500, Train Loss: 0.6004, Val Loss: 0.7662, Learning rate: 0.002500
# Epoch 280/500, Train Loss: 0.6034, Val Loss: 0.7649, Learning rate: 0.002500
# Epoch 281/500, Train Loss: 0.6120, Val Loss: 0.7757, Learning rate: 0.002500
# Epoch 282/500, Train Loss: 0.6159, Val Loss: 0.7682, Learning rate: 0.002500
# Epoch 283/500, Train Loss: 0.6072, Val Loss: 0.7640, Learning rate: 0.002500
# Epoch 284/500, Train Loss: 0.6097, Val Loss: 0.7666, Learning rate: 0.002500
# Epoch 285/500, Train Loss: 0.5995, Val Loss: 0.7817, Learning rate: 0.002500
# Epoch 286/500, Train Loss: 0.6074, Val Loss: 0.7687, Learning rate: 0.002500
# Epoch 287/500, Train Loss: 0.6050, Val Loss: 0.7765, Learning rate: 0.002500
# Epoch 288/500, Train Loss: 0.6066, Val Loss: 0.7660, Learning rate: 0.002500
# Epoch 289/500, Train Loss: 0.6064, Val Loss: 0.7689, Learning rate: 0.002500
# Epoch 290/500, Train Loss: 0.6036, Val Loss: 0.7638, Learning rate: 0.002500
# Epoch 291/500, Train Loss: 0.6050, Val Loss: 0.7695, Learning rate: 0.002500
# Epoch 292/500, Train Loss: 0.6011, Val Loss: 0.7685, Learning rate: 0.002500
# Epoch 293/500, Train Loss: 0.6018, Val Loss: 0.7765, Learning rate: 0.002500
# Epoch 294/500, Train Loss: 0.5945, Val Loss: 0.7712, Learning rate: 0.002500
# Epoch 295/500, Train Loss: 0.6016, Val Loss: 0.7746, Learning rate: 0.002500
# Epoch 296/500, Train Loss: 0.6031, Val Loss: 0.7809, Learning rate: 0.002500
# Epoch 297/500, Train Loss: 0.6017, Val Loss: 0.7696, Learning rate: 0.002500
# Epoch 298/500, Train Loss: 0.6067, Val Loss: 0.7684, Learning rate: 0.002500
# Epoch 299/500, Train Loss: 0.6062, Val Loss: 0.7639, Learning rate: 0.002500
# Epoch 300/500, Train Loss: 0.5976, Val Loss: 0.7653, Learning rate: 0.002500
# RandomAgent score: 0.9
# Minimax draw rate: 0.97
# Epoch 301/500, Train Loss: 0.6064, Val Loss: 0.7734, Learning rate: 0.002500
# Epoch 302/500, Train Loss: 0.5975, Val Loss: 0.7658, Learning rate: 0.002500
# Epoch 303/500, Train Loss: 0.6032, Val Loss: 0.7722, Learning rate: 0.002500
# Epoch 304/500, Train Loss: 0.6059, Val Loss: 0.7677, Learning rate: 0.002500
# Epoch 305/500, Train Loss: 0.6008, Val Loss: 0.7669, Learning rate: 0.002500
# Epoch 306/500, Train Loss: 0.6109, Val Loss: 0.7785, Learning rate: 0.002500
# Epoch 307/500, Train Loss: 0.6081, Val Loss: 0.7712, Learning rate: 0.002500
# Epoch 308/500, Train Loss: 0.5982, Val Loss: 0.7662, Learning rate: 0.002500
# Epoch 309/500, Train Loss: 0.6028, Val Loss: 0.7686, Learning rate: 0.002500
# Epoch 310/500, Train Loss: 0.6044, Val Loss: 0.7707, Learning rate: 0.002500
# Epoch 311/500, Train Loss: 0.6022, Val Loss: 0.7764, Learning rate: 0.002500
# Epoch 312/500, Train Loss: 0.6058, Val Loss: 0.7665, Learning rate: 0.002500
# Epoch 313/500, Train Loss: 0.5986, Val Loss: 0.7673, Learning rate: 0.002500
# Epoch 314/500, Train Loss: 0.6018, Val Loss: 0.7632, Learning rate: 0.001250
# Epoch 315/500, Train Loss: 0.5950, Val Loss: 0.7781, Learning rate: 0.001250
# Epoch 316/500, Train Loss: 0.5890, Val Loss: 0.7662, Learning rate: 0.001250
# Epoch 317/500, Train Loss: 0.5922, Val Loss: 0.7679, Learning rate: 0.001250
# Epoch 318/500, Train Loss: 0.5882, Val Loss: 0.7686, Learning rate: 0.001250
# Epoch 319/500, Train Loss: 0.5920, Val Loss: 0.7651, Learning rate: 0.001250
# Epoch 320/500, Train Loss: 0.5963, Val Loss: 0.7712, Learning rate: 0.001250
# Epoch 321/500, Train Loss: 0.5872, Val Loss: 0.7691, Learning rate: 0.001250
# Epoch 322/500, Train Loss: 0.5942, Val Loss: 0.7708, Learning rate: 0.001250
# Epoch 323/500, Train Loss: 0.5849, Val Loss: 0.7655, Learning rate: 0.001250
# Epoch 324/500, Train Loss: 0.5919, Val Loss: 0.7735, Learning rate: 0.001250
# Epoch 325/500, Train Loss: 0.5935, Val Loss: 0.7733, Learning rate: 0.001250
# Epoch 326/500, Train Loss: 0.5953, Val Loss: 0.7645, Learning rate: 0.001250
# Epoch 327/500, Train Loss: 0.5906, Val Loss: 0.7709, Learning rate: 0.001250
# Epoch 328/500, Train Loss: 0.5878, Val Loss: 0.7687, Learning rate: 0.001250
# Epoch 329/500, Train Loss: 0.5906, Val Loss: 0.7695, Learning rate: 0.001250
# Epoch 330/500, Train Loss: 0.5923, Val Loss: 0.7661, Learning rate: 0.001250
# Epoch 331/500, Train Loss: 0.5933, Val Loss: 0.7696, Learning rate: 0.001250
# Epoch 332/500, Train Loss: 0.5966, Val Loss: 0.7700, Learning rate: 0.001250
# Epoch 333/500, Train Loss: 0.5937, Val Loss: 0.7710, Learning rate: 0.001250
# Epoch 334/500, Train Loss: 0.5931, Val Loss: 0.7675, Learning rate: 0.001250
# Epoch 335/500, Train Loss: 0.5924, Val Loss: 0.7691, Learning rate: 0.001250
# Epoch 336/500, Train Loss: 0.5871, Val Loss: 0.7755, Learning rate: 0.001250
# Epoch 337/500, Train Loss: 0.5934, Val Loss: 0.7681, Learning rate: 0.001250
# Epoch 338/500, Train Loss: 0.5915, Val Loss: 0.7655, Learning rate: 0.001250
# Epoch 339/500, Train Loss: 0.5932, Val Loss: 0.7686, Learning rate: 0.001250
# Epoch 340/500, Train Loss: 0.5923, Val Loss: 0.7703, Learning rate: 0.001250
# Epoch 341/500, Train Loss: 0.5932, Val Loss: 0.7716, Learning rate: 0.001250
# Epoch 342/500, Train Loss: 0.5930, Val Loss: 0.7748, Learning rate: 0.001250
# Epoch 343/500, Train Loss: 0.5952, Val Loss: 0.7710, Learning rate: 0.001250
# Epoch 344/500, Train Loss: 0.5921, Val Loss: 0.7695, Learning rate: 0.001250
# Epoch 345/500, Train Loss: 0.5943, Val Loss: 0.7729, Learning rate: 0.001250
# Epoch 346/500, Train Loss: 0.5899, Val Loss: 0.7677, Learning rate: 0.001250
# Epoch 347/500, Train Loss: 0.5967, Val Loss: 0.7722, Learning rate: 0.001250
# Epoch 348/500, Train Loss: 0.5895, Val Loss: 0.7765, Learning rate: 0.001250
# Epoch 349/500, Train Loss: 0.5938, Val Loss: 0.7766, Learning rate: 0.001250
# Epoch 350/500, Train Loss: 0.5950, Val Loss: 0.7695, Learning rate: 0.001250
# RandomAgent score: 0.89
# Minimax draw rate: 1.0
# Epoch 351/500, Train Loss: 0.5878, Val Loss: 0.7698, Learning rate: 0.001250
# Epoch 352/500, Train Loss: 0.5907, Val Loss: 0.7669, Learning rate: 0.001250
# Epoch 353/500, Train Loss: 0.5861, Val Loss: 0.7716, Learning rate: 0.001250
# Epoch 354/500, Train Loss: 0.5902, Val Loss: 0.7736, Learning rate: 0.001250
# Epoch 355/500, Train Loss: 0.5855, Val Loss: 0.7737, Learning rate: 0.001250
# Epoch 356/500, Train Loss: 0.5884, Val Loss: 0.7713, Learning rate: 0.001250
# Epoch 357/500, Train Loss: 0.5917, Val Loss: 0.7755, Learning rate: 0.001250
# Epoch 358/500, Train Loss: 0.5945, Val Loss: 0.7721, Learning rate: 0.001250
# Epoch 359/500, Train Loss: 0.5907, Val Loss: 0.7714, Learning rate: 0.001250
# Epoch 360/500, Train Loss: 0.5921, Val Loss: 0.7704, Learning rate: 0.001250
# Epoch 361/500, Train Loss: 0.5924, Val Loss: 0.7723, Learning rate: 0.001250
# Epoch 362/500, Train Loss: 0.5867, Val Loss: 0.7693, Learning rate: 0.001250
# Epoch 363/500, Train Loss: 0.5833, Val Loss: 0.7718, Learning rate: 0.001250
# Epoch 364/500, Train Loss: 0.5860, Val Loss: 0.7745, Learning rate: 0.001250
# Epoch 365/500, Train Loss: 0.5947, Val Loss: 0.7742, Learning rate: 0.001250
# Epoch 366/500, Train Loss: 0.5897, Val Loss: 0.7766, Learning rate: 0.001250
# Epoch 367/500, Train Loss: 0.5950, Val Loss: 0.7803, Learning rate: 0.001250
# Epoch 368/500, Train Loss: 0.5959, Val Loss: 0.7786, Learning rate: 0.001250
# Epoch 369/500, Train Loss: 0.5865, Val Loss: 0.7695, Learning rate: 0.001250
# Epoch 370/500, Train Loss: 0.5914, Val Loss: 0.7725, Learning rate: 0.001250
# Epoch 371/500, Train Loss: 0.5882, Val Loss: 0.7804, Learning rate: 0.001250
# Epoch 372/500, Train Loss: 0.5874, Val Loss: 0.7748, Learning rate: 0.001250
# Epoch 373/500, Train Loss: 0.5918, Val Loss: 0.7680, Learning rate: 0.001250
# Epoch 374/500, Train Loss: 0.5882, Val Loss: 0.7724, Learning rate: 0.001250
# Epoch 375/500, Train Loss: 0.5928, Val Loss: 0.7705, Learning rate: 0.001250
# Epoch 376/500, Train Loss: 0.5899, Val Loss: 0.7733, Learning rate: 0.001250
# Epoch 377/500, Train Loss: 0.5901, Val Loss: 0.7770, Learning rate: 0.001250
# Epoch 378/500, Train Loss: 0.5897, Val Loss: 0.7731, Learning rate: 0.001250
# Epoch 379/500, Train Loss: 0.5910, Val Loss: 0.7735, Learning rate: 0.001250
# Epoch 380/500, Train Loss: 0.5868, Val Loss: 0.7708, Learning rate: 0.001250
# Epoch 381/500, Train Loss: 0.5887, Val Loss: 0.7741, Learning rate: 0.001250
# Epoch 382/500, Train Loss: 0.5830, Val Loss: 0.7718, Learning rate: 0.001250
# Epoch 383/500, Train Loss: 0.5880, Val Loss: 0.7762, Learning rate: 0.001250
# Epoch 384/500, Train Loss: 0.5903, Val Loss: 0.7823, Learning rate: 0.001250
# Epoch 385/500, Train Loss: 0.5858, Val Loss: 0.7786, Learning rate: 0.001250
# Epoch 386/500, Train Loss: 0.5868, Val Loss: 0.7724, Learning rate: 0.001250
# Epoch 387/500, Train Loss: 0.5878, Val Loss: 0.7716, Learning rate: 0.001250
# Epoch 388/500, Train Loss: 0.5872, Val Loss: 0.7720, Learning rate: 0.001250
# Epoch 389/500, Train Loss: 0.5858, Val Loss: 0.7707, Learning rate: 0.001250
# Epoch 390/500, Train Loss: 0.5863, Val Loss: 0.7769, Learning rate: 0.001250
# Epoch 391/500, Train Loss: 0.5830, Val Loss: 0.7738, Learning rate: 0.001250
# Epoch 392/500, Train Loss: 0.5841, Val Loss: 0.7699, Learning rate: 0.001250
# Epoch 393/500, Train Loss: 0.5931, Val Loss: 0.7710, Learning rate: 0.001250
# Epoch 394/500, Train Loss: 0.5840, Val Loss: 0.7753, Learning rate: 0.001250
# Epoch 395/500, Train Loss: 0.5872, Val Loss: 0.7687, Learning rate: 0.001250
# Epoch 396/500, Train Loss: 0.5852, Val Loss: 0.7733, Learning rate: 0.001250
# Epoch 397/500, Train Loss: 0.5831, Val Loss: 0.7692, Learning rate: 0.001250
# Epoch 398/500, Train Loss: 0.5865, Val Loss: 0.7727, Learning rate: 0.001250
# Epoch 399/500, Train Loss: 0.5891, Val Loss: 0.7710, Learning rate: 0.001250
# Epoch 400/500, Train Loss: 0.5831, Val Loss: 0.7738, Learning rate: 0.001250
# RandomAgent score: 0.97
# Minimax draw rate: 1.0
# Epoch 401/500, Train Loss: 0.5789, Val Loss: 0.7709, Learning rate: 0.001250
# Epoch 402/500, Train Loss: 0.5932, Val Loss: 0.7732, Learning rate: 0.001250
# Epoch 403/500, Train Loss: 0.5909, Val Loss: 0.7722, Learning rate: 0.001250
# Epoch 404/500, Train Loss: 0.5852, Val Loss: 0.7756, Learning rate: 0.001250
# Epoch 405/500, Train Loss: 0.5919, Val Loss: 0.7750, Learning rate: 0.001250
# Epoch 406/500, Train Loss: 0.5816, Val Loss: 0.7725, Learning rate: 0.001250
# Epoch 407/500, Train Loss: 0.5861, Val Loss: 0.7782, Learning rate: 0.001250
# Epoch 408/500, Train Loss: 0.5858, Val Loss: 0.7787, Learning rate: 0.001250
# Epoch 409/500, Train Loss: 0.5889, Val Loss: 0.7802, Learning rate: 0.001250
# Epoch 410/500, Train Loss: 0.5840, Val Loss: 0.7768, Learning rate: 0.001250
# Epoch 411/500, Train Loss: 0.5940, Val Loss: 0.7724, Learning rate: 0.001250
# Epoch 412/500, Train Loss: 0.5880, Val Loss: 0.7838, Learning rate: 0.001250
# Epoch 413/500, Train Loss: 0.5862, Val Loss: 0.7764, Learning rate: 0.001250
# Epoch 414/500, Train Loss: 0.5863, Val Loss: 0.7701, Learning rate: 0.001250
# Epoch 415/500, Train Loss: 0.5896, Val Loss: 0.7704, Learning rate: 0.001250
# Epoch 416/500, Train Loss: 0.5842, Val Loss: 0.7776, Learning rate: 0.001250
# Epoch 417/500, Train Loss: 0.5857, Val Loss: 0.7698, Learning rate: 0.001250
# Epoch 418/500, Train Loss: 0.5825, Val Loss: 0.7751, Learning rate: 0.001250
# Epoch 419/500, Train Loss: 0.5830, Val Loss: 0.7724, Learning rate: 0.001250
# Epoch 420/500, Train Loss: 0.5900, Val Loss: 0.7801, Learning rate: 0.001250
# Epoch 421/500, Train Loss: 0.5927, Val Loss: 0.7737, Learning rate: 0.001250
# Epoch 422/500, Train Loss: 0.5876, Val Loss: 0.7791, Learning rate: 0.001250
# Epoch 423/500, Train Loss: 0.5864, Val Loss: 0.7771, Learning rate: 0.001250
# Epoch 424/500, Train Loss: 0.5890, Val Loss: 0.7725, Learning rate: 0.001250
# Epoch 425/500, Train Loss: 0.5851, Val Loss: 0.7763, Learning rate: 0.001250
# Epoch 426/500, Train Loss: 0.5844, Val Loss: 0.7817, Learning rate: 0.001250
# Epoch 427/500, Train Loss: 0.5797, Val Loss: 0.7784, Learning rate: 0.001250
# Epoch 428/500, Train Loss: 0.5822, Val Loss: 0.7840, Learning rate: 0.001250
# Epoch 429/500, Train Loss: 0.5848, Val Loss: 0.7798, Learning rate: 0.001250
# Epoch 430/500, Train Loss: 0.5846, Val Loss: 0.7777, Learning rate: 0.001250
# Epoch 431/500, Train Loss: 0.5815, Val Loss: 0.7769, Learning rate: 0.001250
# Epoch 432/500, Train Loss: 0.5842, Val Loss: 0.7752, Learning rate: 0.001250
# Epoch 433/500, Train Loss: 0.5895, Val Loss: 0.7829, Learning rate: 0.001250
# Epoch 434/500, Train Loss: 0.5824, Val Loss: 0.7793, Learning rate: 0.001250
# Epoch 435/500, Train Loss: 0.5814, Val Loss: 0.7792, Learning rate: 0.000625
# Epoch 436/500, Train Loss: 0.5776, Val Loss: 0.7793, Learning rate: 0.000625
# Epoch 437/500, Train Loss: 0.5745, Val Loss: 0.7795, Learning rate: 0.000625
# Epoch 438/500, Train Loss: 0.5867, Val Loss: 0.7754, Learning rate: 0.000625
# Epoch 439/500, Train Loss: 0.5795, Val Loss: 0.7737, Learning rate: 0.000625
# Epoch 440/500, Train Loss: 0.5789, Val Loss: 0.7777, Learning rate: 0.000625
# Epoch 441/500, Train Loss: 0.5755, Val Loss: 0.7773, Learning rate: 0.000625
# Epoch 442/500, Train Loss: 0.5781, Val Loss: 0.7789, Learning rate: 0.000625
# Epoch 443/500, Train Loss: 0.5772, Val Loss: 0.7781, Learning rate: 0.000625
# Epoch 444/500, Train Loss: 0.5797, Val Loss: 0.7768, Learning rate: 0.000625
# Epoch 445/500, Train Loss: 0.5773, Val Loss: 0.7793, Learning rate: 0.000625
# Epoch 446/500, Train Loss: 0.5859, Val Loss: 0.7760, Learning rate: 0.000625
# Epoch 447/500, Train Loss: 0.5753, Val Loss: 0.7802, Learning rate: 0.000625
# Epoch 448/500, Train Loss: 0.5771, Val Loss: 0.7761, Learning rate: 0.000625
# Epoch 449/500, Train Loss: 0.5770, Val Loss: 0.7808, Learning rate: 0.000625
# Epoch 450/500, Train Loss: 0.5742, Val Loss: 0.7792, Learning rate: 0.000625
# RandomAgent score: 0.89
# Minimax draw rate: 1.0
# Epoch 451/500, Train Loss: 0.5800, Val Loss: 0.7764, Learning rate: 0.000625
# Epoch 452/500, Train Loss: 0.5788, Val Loss: 0.7754, Learning rate: 0.000625
# Epoch 453/500, Train Loss: 0.5793, Val Loss: 0.7797, Learning rate: 0.000625
# Epoch 454/500, Train Loss: 0.5735, Val Loss: 0.7775, Learning rate: 0.000625
# Epoch 455/500, Train Loss: 0.5807, Val Loss: 0.7768, Learning rate: 0.000625
# Epoch 456/500, Train Loss: 0.5772, Val Loss: 0.7778, Learning rate: 0.000625
# Epoch 457/500, Train Loss: 0.5730, Val Loss: 0.7765, Learning rate: 0.000625
# Epoch 458/500, Train Loss: 0.5751, Val Loss: 0.7781, Learning rate: 0.000625
# Epoch 459/500, Train Loss: 0.5751, Val Loss: 0.7830, Learning rate: 0.000625
# Epoch 460/500, Train Loss: 0.5738, Val Loss: 0.7766, Learning rate: 0.000625
# Epoch 461/500, Train Loss: 0.5793, Val Loss: 0.7786, Learning rate: 0.000625
# Epoch 462/500, Train Loss: 0.5742, Val Loss: 0.7769, Learning rate: 0.000625
# Epoch 463/500, Train Loss: 0.5817, Val Loss: 0.7787, Learning rate: 0.000625
# Epoch 464/500, Train Loss: 0.5820, Val Loss: 0.7799, Learning rate: 0.000625
# Epoch 465/500, Train Loss: 0.5779, Val Loss: 0.7818, Learning rate: 0.000625
# Epoch 466/500, Train Loss: 0.5818, Val Loss: 0.7770, Learning rate: 0.000625
# Epoch 467/500, Train Loss: 0.5788, Val Loss: 0.7798, Learning rate: 0.000625
# Epoch 468/500, Train Loss: 0.5810, Val Loss: 0.7767, Learning rate: 0.000625
# Epoch 469/500, Train Loss: 0.5754, Val Loss: 0.7809, Learning rate: 0.000625
# Epoch 470/500, Train Loss: 0.5766, Val Loss: 0.7819, Learning rate: 0.000625
# Epoch 471/500, Train Loss: 0.5793, Val Loss: 0.7792, Learning rate: 0.000625
# Epoch 472/500, Train Loss: 0.5735, Val Loss: 0.7825, Learning rate: 0.000625
# Epoch 473/500, Train Loss: 0.5728, Val Loss: 0.7746, Learning rate: 0.000625
# Epoch 474/500, Train Loss: 0.5791, Val Loss: 0.7808, Learning rate: 0.000625
# Epoch 475/500, Train Loss: 0.5724, Val Loss: 0.7800, Learning rate: 0.000625
# Epoch 476/500, Train Loss: 0.5761, Val Loss: 0.7817, Learning rate: 0.000625
# Epoch 477/500, Train Loss: 0.5767, Val Loss: 0.7795, Learning rate: 0.000625
# Epoch 478/500, Train Loss: 0.5725, Val Loss: 0.7802, Learning rate: 0.000625
# Epoch 479/500, Train Loss: 0.5742, Val Loss: 0.7802, Learning rate: 0.000625
# Epoch 480/500, Train Loss: 0.5777, Val Loss: 0.7828, Learning rate: 0.000625
# Epoch 481/500, Train Loss: 0.5782, Val Loss: 0.7781, Learning rate: 0.000625
# Epoch 482/500, Train Loss: 0.5760, Val Loss: 0.7820, Learning rate: 0.000625
# Epoch 483/500, Train Loss: 0.5802, Val Loss: 0.7767, Learning rate: 0.000625
# Epoch 484/500, Train Loss: 0.5743, Val Loss: 0.7806, Learning rate: 0.000625
# Epoch 485/500, Train Loss: 0.5785, Val Loss: 0.7828, Learning rate: 0.000625
# Epoch 486/500, Train Loss: 0.5759, Val Loss: 0.7811, Learning rate: 0.000625
# Epoch 487/500, Train Loss: 0.5775, Val Loss: 0.7817, Learning rate: 0.000625
# Epoch 488/500, Train Loss: 0.5752, Val Loss: 0.7826, Learning rate: 0.000625
# Epoch 489/500, Train Loss: 0.5764, Val Loss: 0.7859, Learning rate: 0.000625
# Epoch 490/500, Train Loss: 0.5756, Val Loss: 0.7820, Learning rate: 0.000625
# Epoch 491/500, Train Loss: 0.5771, Val Loss: 0.7806, Learning rate: 0.000625
# Epoch 492/500, Train Loss: 0.5770, Val Loss: 0.7812, Learning rate: 0.000625
# Epoch 493/500, Train Loss: 0.5754, Val Loss: 0.7803, Learning rate: 0.000625
# Epoch 494/500, Train Loss: 0.5711, Val Loss: 0.7814, Learning rate: 0.000625
# Epoch 495/500, Train Loss: 0.5779, Val Loss: 0.7821, Learning rate: 0.000625
# Epoch 496/500, Train Loss: 0.5735, Val Loss: 0.7833, Learning rate: 0.000625
# Epoch 497/500, Train Loss: 0.5753, Val Loss: 0.7821, Learning rate: 0.000625
# Epoch 498/500, Train Loss: 0.5764, Val Loss: 0.7781, Learning rate: 0.000625
# Epoch 499/500, Train Loss: 0.5726, Val Loss: 0.7818, Learning rate: 0.000625
# RandomAgent score: 1.0
# Minimax draw rate: 1.0
# Epoch 500/500, Train Loss: 0.5787, Val Loss: 0.7828, Learning rate: 0.000625
# RandomAgent score: 0.94
# Minimax draw rate: 1.0

# %%
wandb.finish(exit_code=0)
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>learning_rate</td><td>█████▄▄▄▄▄▄▄▄▄▄▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>minimax_draw_rate</td><td>▁▆▅▇█▅█████</td></tr><tr><td>minimax_loss_rate</td><td>█▃▄▂▁▄▁▁▁▁▁</td></tr><tr><td>minimax_score</td><td>▁▆▅▇█▅█████</td></tr><tr><td>minimax_win_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>random_draw_rate</td><td>▆▂▅▅▇▇█▃█▁▅</td></tr><tr><td>random_loss_rate</td><td>█▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>random_score</td><td>▂▇▄▄▂▂▁▆▁█▄</td></tr><tr><td>random_win_rate</td><td>▂▇▄▄▂▂▁▆▁█▄</td></tr><tr><td>train_loss</td><td>█▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_policy_loss</td><td>█▇▅▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_value_loss</td><td>█▄▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_policy_loss</td><td>█▆▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_value_loss</td><td>█▅▇▆▆▃▁▄▆▃▃▂▃▆▃▆▄▅▅▅▃▂▂▃▂▂▃▂▂▂▃▃▂▂▃▃▃▃▂▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>500</td></tr><tr><td>learning_rate</td><td>0.00063</td></tr><tr><td>minimax_draw_rate</td><td>1</td></tr><tr><td>minimax_loss_rate</td><td>0</td></tr><tr><td>minimax_score</td><td>0</td></tr><tr><td>minimax_win_rate</td><td>0</td></tr><tr><td>random_draw_rate</td><td>0.06</td></tr><tr><td>random_loss_rate</td><td>0</td></tr><tr><td>random_score</td><td>0.94</td></tr><tr><td>random_win_rate</td><td>0.94</td></tr><tr><td>train_loss</td><td>0.5787</td></tr><tr><td>train_policy_loss</td><td>0.54896</td></tr><tr><td>train_value_loss</td><td>0.02974</td></tr><tr><td>val_loss</td><td>0.78284</td></tr><tr><td>val_policy_loss</td><td>0.67658</td></tr><tr><td>val_value_loss</td><td>0.10626</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">peach-flan-221</strong> at: <a href='https://wandb.ai/eigenway/AlphaZero-TicTacToe/runs/5ifssm24' target="_blank">https://wandb.ai/eigenway/AlphaZero-TicTacToe/runs/5ifssm24</a><br> View project at: <a href='https://wandb.ai/eigenway/AlphaZero-TicTacToe' target="_blank">https://wandb.ai/eigenway/AlphaZero-TicTacToe</a><br>Synced 5 W&B file(s), 1 media file(s), 68 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250314_092348-5ifssm24/logs</code>
