# %%
# Change directory to the root of the project
import os 
os.chdir('..')
print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: /Users/eohjelle/Documents/2025-dots-and-boxes/dots-and-boxes

# %% [markdown]
# In this notebook we will do single runs for a transformer based model using training data generated with a Minimax model. This is based on tic_tac_toe_transformer_sweep_2.ipynb.

# %%
# Load the training data

from core.data_structures import ReplayBuffer
import random

buffer = ReplayBuffer.from_file('applications/tic_tac_toe/training_data/transformer.pkl')

print(f"Buffer size: {buffer.states.shape[0]}")
for i in random.sample(range(buffer.states.shape[0]), 1):
    print(f"Buffer state {i}: {buffer.states[i]}")
    for key in buffer.targets.keys():
        print(f"Buffer target {key} {i}: {buffer.targets[key][i]}")
    for key in buffer.data.keys():
        print(f"Buffer data {key} {i}: {buffer.data[key][i]}")
# Out:
# /Users/eohjelle/Documents/2025-dots-and-boxes/dots-and-boxes/core/data_structures.py:91: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path, map_location=device)
# Buffer size: 5478
# Buffer state 1390: tensor([1, 0, 0, 2, 2, 1, 0, 2, 1], device='mps:0')
# Buffer target policy 1390: tensor([0., 0., 1., 0., 0., 0., 0., 0., 0.], device='mps:0')
# Buffer target value 1390: tensor([1.], device='mps:0')
# Buffer data legal_actions 1390: tensor([0., 1., 1., 0., 0., 0., 1., 0., 0.], device='mps:0')

# %%
from applications.tic_tac_toe.game_state import TicTacToeState
from core.implementations.Minimax import Minimax

# Creat minmax agent and expand the game tree, this will be used for evaluation later on
state = TicTacToeState()
minimax_agent = Minimax(state)
minimax_agent_root = minimax_agent.root
minimax_agent()

def minimax_agent_factory() -> Minimax:
    """
    This function returns a minimax agent that is initialized with the root of the game tree.
    """
    minimax_agent.root = minimax_agent_root
    return minimax_agent

# %%
# Define config

config = {
    # Optimizer parameters
    'learning_rate': 0.01,
    'weight_decay': 0.0001,

    # Learning rate scheduler parameters
    'lr_scheduler': 'plateau',  # Options: 'step', 'multistep', 'exponential', 'cosine', 'plateau'
    'lr_eta_min': 1e-6, # For CosineAnnealingLR
    'lr_step_size': 30,  # For StepLR
    'lr_gamma': 0.1,  # For StepLR, MultiStepLR, ExponentialLR, ReduceLROnPlateau
    'lr_milestones': [30, 60, 90],  # For MultiStepLR
    'lr_t_max': 1000,  # For CosineAnnealingLR (usually set to total epochs)
    'lr_patience': 100,  # For ReduceLROnPlateau
    'lr_cooldown': 100,  # For ReduceLROnPlateau

    # Model parameters
    'attention_layers': 1,
    'embed_dim': 64,
    'output_head_dim': 32,
    'feedforward_dim': 256,
    'dropout': 0.0,
    'norm_first': True,
    'activation': 'gelu',

    # Training parameters
    'epochs': 1000,
    'batch_size': 256,
    'mask_illegal_moves': False,
    'mask_value': -10.0,
    'eval_freq': 50
}

# %%
# Define simple training loop

import wandb
from applications.tic_tac_toe.game_state import TicTacToeState
from applications.tic_tac_toe.transformer_model import TicTacToeTransformerInterface
import torch
import torch.nn.functional as F
import numpy as np
from torch.utils.data import DataLoader, TensorDataset, random_split
from core.benchmark import benchmark
from core.implementations.RandomAgent import RandomAgent
from core.implementations.AlphaZero import AlphaZeroModelAgent

def do_run(run):
    config = run.config
    device = torch.device("cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu")
    model_interface = TicTacToeTransformerInterface(
        device=device,
        attention_layers=config.attention_layers,
        embed_dim=config.embed_dim,
        num_heads=4,
        feedforward_dim=config.feedforward_dim,
        dropout=config.dropout,
        norm_first=config.norm_first,
        activation=config.activation
    )
    model = model_interface.model

    wandb.watch(
        models=model,
        log="all",
        log_freq=20,
        log_graph=True
    )
    
    # Create optimizer
    optimizer = torch.optim.Adam(
        model.parameters(), 
        lr=config.learning_rate,
        weight_decay=config.weight_decay
    )

    # Create learning rate scheduler
    match config['lr_scheduler']:
        case 'step':
            scheduler = torch.optim.lr_scheduler.StepLR(
                optimizer, 
                step_size=config['lr_step_size'], 
                gamma=config['lr_gamma']
            )
        case 'multistep':
            scheduler = torch.optim.lr_scheduler.MultiStepLR(
                optimizer, 
                milestones=config['lr_milestones'], 
                gamma=config['lr_gamma']
            )
        case 'exponential':
            scheduler = torch.optim.lr_scheduler.ExponentialLR(
                optimizer, 
                gamma=config['lr_gamma']
                )
        case 'cosine':
            scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
                optimizer, 
                T_max=config['lr_t_max'],
                eta_min=1e-6
            )
        case 'plateau':
            scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
                optimizer, 
                mode='min', 
                factor=config['lr_gamma'], 
                patience=config['lr_patience'],
                cooldown=config['lr_cooldown']
            )
        case _:
            scheduler = None

    print(f"Using learning rate scheduler: {config['lr_scheduler']}")
    
    # Create datasets
    states = buffer.states
    policy_targets = buffer.targets['policy']
    value_targets = buffer.targets['value']
    legal_actions_mask = buffer.data['legal_actions']
    
    # Create dataset and split into train/val
    dataset = TensorDataset(states, policy_targets, value_targets, legal_actions_mask)
    train_size = int(0.9 * len(dataset))
    val_size = len(dataset) - train_size
    train_dataset, val_dataset = random_split(dataset, [train_size, val_size])
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=config.batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=config.batch_size, shuffle=False)
    
    # Training loop
    best_val_loss = float('inf')
    
    for epoch in range(config.epochs):
        # Training phase
        model.train()
        train_losses = []
        policy_losses = []
        value_losses = []
        
        for batch in train_loader:
            states_batch, policy_targets_batch, value_targets_batch, legal_actions_batch = batch
            
            # Zero gradients
            optimizer.zero_grad()
            
            # Forward pass
            outputs = model(states_batch)
            policy_logits = outputs['policy']
            value_pred = outputs['value']
            
            # Apply mask for illegal moves if enabled
            if config.mask_illegal_moves:
                policy_logits = policy_logits * legal_actions_batch + (1 - legal_actions_batch) * config.mask_value
            
            # Compute losses
            policy_loss = F.cross_entropy(policy_logits, policy_targets_batch)
            value_loss = F.mse_loss(value_pred, value_targets_batch)
            total_loss = policy_loss + value_loss
            
            # Backward pass and optimization
            total_loss.backward()
            optimizer.step()
            
            # Track metrics
            train_losses.append(total_loss.item())
            policy_losses.append(policy_loss.item())
            value_losses.append(value_loss.item())
        
        # Validation phase
        model.eval()
        val_losses = []
        val_policy_losses = []
        val_value_losses = []
        
        with torch.no_grad():
            for batch in val_loader:
                states_batch, policy_targets_batch, value_targets_batch, legal_actions_batch = batch
                
                # Forward pass
                outputs = model(states_batch)
                policy_logits = outputs['policy']
                value_pred = outputs['value']
                
                # Apply mask for illegal moves if enabled
                if config.mask_illegal_moves:
                    policy_logits = policy_logits * legal_actions_batch + (1 - legal_actions_batch) * config.mask_value
                
                # Compute losses
                policy_loss = F.cross_entropy(policy_logits, policy_targets_batch)
                value_loss = F.mse_loss(value_pred, value_targets_batch)
                total_loss = policy_loss + value_loss
                
                # Track metrics
                val_losses.append(total_loss.item())
                val_policy_losses.append(policy_loss.item())
                val_value_losses.append(value_loss.item())
        
        # Calculate average metrics
        avg_train_loss = np.mean(train_losses)
        avg_val_loss = np.mean(val_losses)
        
        current_lr = optimizer.param_groups[0]['lr']

        # Log metrics to wandb
        wandb.log({
            "epoch": epoch,
            "train_loss": avg_train_loss,
            "train_policy_loss": np.mean(policy_losses),
            "train_value_loss": np.mean(value_losses),
            "val_loss": avg_val_loss,
            "val_policy_loss": np.mean(val_policy_losses),
            "val_value_loss": np.mean(val_value_losses),
            "learning_rate": current_lr
        }, step=epoch)
        
        print(f"Epoch {epoch+1}/{config.epochs}, "
                f"Train Loss: {avg_train_loss:.4f}, "
                f"Val Loss: {avg_val_loss:.4f}, "
                f"Learning rate: {current_lr:.6f}")
        
        # Update the learning rate scheduler
        if scheduler is not None:

            # Update scheduler based on its actual type
            if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau):
                scheduler.step(avg_val_loss)  # ReduceLROnPlateau needs a metric
            else:
                scheduler.step()  # All other schedulers just need step()
    
        
        # # Save best model
        # if avg_val_loss < best_val_loss:
        #     best_val_loss = avg_val_loss
            
        #     # Save model checkpoint
        #     if not os.path.exists('checkpoints'):
        #         os.makedirs('checkpoints')
                
        #     checkpoint_path = f"checkpoints/transformer_best_{run.id}.pt"
        #     torch.save({
        #         'epoch': epoch,
        #         'model_state_dict': model.state_dict(),
        #         'optimizer_state_dict': optimizer.state_dict(),
        #         'loss': best_val_loss,
        #         'config': dict(config)
        #     }, checkpoint_path)
            
        #     # Save as W&B artifact
        #     model_artifact = wandb.Artifact(
        #         f"transformer_model_{run.id}", 
        #         type="model",
        #         description=f"Best model with val_loss: {best_val_loss:.4f}"
        #     )
        #     model_artifact.add_file(checkpoint_path)
        #     run.log_artifact(model_artifact)

        # Evaluate against agents
        if epoch % config.eval_freq == 0 or epoch == config.epochs - 1:
            stats = benchmark(
                create_agent=lambda state: AlphaZeroModelAgent(
                    initial_state=state,
                    model=model_interface,
                    temperature=0.0
                ),
                create_opponents={
                    'random': lambda state: RandomAgent(state),
                    'minimax': lambda state: minimax_agent_factory()
                },
                initial_state=lambda: TicTacToeState(),
                num_games=100
            )
            print(f"RandomAgent score: {stats['random']['win_rate'] - stats['random']['loss_rate']}")
            print(f"Minimax draw rate: {stats['minimax']['draw_rate']}")
            wandb.log({
                'random_win_rate': stats['random']['win_rate'],
                'minimax_win_rate': stats['minimax']['win_rate'],
                'random_draw_rate': stats['random']['draw_rate'],
                'minimax_draw_rate': stats['minimax']['draw_rate'],
                'random_loss_rate': stats['random']['loss_rate'],
                'minimax_loss_rate': stats['minimax']['loss_rate'],
                'random_score': stats['random']['win_rate'] - stats['random']['loss_rate'],
                'minimax_score': stats['minimax']['win_rate'] - stats['minimax']['loss_rate']
            })

# %%
run = wandb.init(
    project="AlphaZero-TicTacToe",
    id=None,
    config=config
)
do_run(run)
# Out:
# wandb: Currently logged in as: eohjelle (eigenway) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.6
# Run data is saved locally in <code>/Users/eohjelle/Documents/2025-dots-and-boxes/dots-and-boxes/wandb/run-20250307_073948-xnyixmrz</code>
# Syncing run <strong><a href='https://wandb.ai/eigenway/AlphaZero-TicTacToe/runs/xnyixmrz' target="_blank">deep-silence-206</a></strong> to <a href='https://wandb.ai/eigenway/AlphaZero-TicTacToe' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/eigenway/AlphaZero-TicTacToe' target="_blank">https://wandb.ai/eigenway/AlphaZero-TicTacToe</a>
#  View run at <a href='https://wandb.ai/eigenway/AlphaZero-TicTacToe/runs/xnyixmrz' target="_blank">https://wandb.ai/eigenway/AlphaZero-TicTacToe/runs/xnyixmrz</a>
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# Using learning rate scheduler: plateau
# /var/folders/22/9ys3dbcs5yb0wn1j_xcbb4600000gn/T/ipykernel_63905/3228332811.py:124: UserWarning: Using a target size (torch.Size([256, 1])) that is different to the input size (torch.Size([256])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   value_loss = F.mse_loss(value_pred, value_targets_batch)
# /var/folders/22/9ys3dbcs5yb0wn1j_xcbb4600000gn/T/ipykernel_63905/3228332811.py:124: UserWarning: Using a target size (torch.Size([66, 1])) that is different to the input size (torch.Size([66])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   value_loss = F.mse_loss(value_pred, value_targets_batch)
# /var/folders/22/9ys3dbcs5yb0wn1j_xcbb4600000gn/T/ipykernel_63905/3228332811.py:157: UserWarning: Using a target size (torch.Size([256, 1])) that is different to the input size (torch.Size([256])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   value_loss = F.mse_loss(value_pred, value_targets_batch)
# /var/folders/22/9ys3dbcs5yb0wn1j_xcbb4600000gn/T/ipykernel_63905/3228332811.py:157: UserWarning: Using a target size (torch.Size([36, 1])) that is different to the input size (torch.Size([36])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   value_loss = F.mse_loss(value_pred, value_targets_batch)
# Epoch 1/1000, Train Loss: 2.5033, Val Loss: 2.1704, Learning rate: 0.010000
# RandomAgent score: 0.06
# Minimax draw rate: 0.07
# Epoch 2/1000, Train Loss: 2.0002, Val Loss: 1.8365, Learning rate: 0.010000
# Epoch 3/1000, Train Loss: 1.7489, Val Loss: 1.7526, Learning rate: 0.010000
# Epoch 4/1000, Train Loss: 1.7154, Val Loss: 1.6805, Learning rate: 0.010000
# Epoch 5/1000, Train Loss: 1.6869, Val Loss: 1.6783, Learning rate: 0.010000
# Epoch 6/1000, Train Loss: 1.6630, Val Loss: 1.5962, Learning rate: 0.010000
# Epoch 7/1000, Train Loss: 1.6181, Val Loss: 1.5915, Learning rate: 0.010000
# Epoch 8/1000, Train Loss: 1.5894, Val Loss: 1.5733, Learning rate: 0.010000
# Epoch 9/1000, Train Loss: 1.5843, Val Loss: 1.5469, Learning rate: 0.010000
# Epoch 10/1000, Train Loss: 1.5540, Val Loss: 1.5290, Learning rate: 0.010000
# Epoch 11/1000, Train Loss: 1.5509, Val Loss: 1.5229, Learning rate: 0.010000
# Epoch 12/1000, Train Loss: 1.5326, Val Loss: 1.4920, Learning rate: 0.010000
# Epoch 13/1000, Train Loss: 1.5099, Val Loss: 1.5101, Learning rate: 0.010000
# Epoch 14/1000, Train Loss: 1.4966, Val Loss: 1.4879, Learning rate: 0.010000
# Epoch 15/1000, Train Loss: 1.4837, Val Loss: 1.4623, Learning rate: 0.010000
# Epoch 16/1000, Train Loss: 1.4816, Val Loss: 1.4937, Learning rate: 0.010000
# Epoch 17/1000, Train Loss: 1.4711, Val Loss: 1.5319, Learning rate: 0.010000
# Epoch 18/1000, Train Loss: 1.4740, Val Loss: 1.4879, Learning rate: 0.010000
# Epoch 19/1000, Train Loss: 1.4562, Val Loss: 1.4752, Learning rate: 0.010000
# Epoch 20/1000, Train Loss: 1.4427, Val Loss: 1.4873, Learning rate: 0.010000
# Epoch 21/1000, Train Loss: 1.4349, Val Loss: 1.4419, Learning rate: 0.010000
# Epoch 22/1000, Train Loss: 1.4311, Val Loss: 1.4883, Learning rate: 0.010000
# Epoch 23/1000, Train Loss: 1.4276, Val Loss: 1.4488, Learning rate: 0.010000
# Epoch 24/1000, Train Loss: 1.4139, Val Loss: 1.4481, Learning rate: 0.010000
# Epoch 25/1000, Train Loss: 1.4099, Val Loss: 1.4766, Learning rate: 0.010000
# Epoch 26/1000, Train Loss: 1.4034, Val Loss: 1.4722, Learning rate: 0.010000
# Epoch 27/1000, Train Loss: 1.4065, Val Loss: 1.4585, Learning rate: 0.010000
# Epoch 28/1000, Train Loss: 1.4001, Val Loss: 1.4398, Learning rate: 0.010000
# Epoch 29/1000, Train Loss: 1.4068, Val Loss: 1.4227, Learning rate: 0.010000
# Epoch 30/1000, Train Loss: 1.3925, Val Loss: 1.4476, Learning rate: 0.010000
# Epoch 31/1000, Train Loss: 1.3952, Val Loss: 1.4347, Learning rate: 0.010000
# Epoch 32/1000, Train Loss: 1.3789, Val Loss: 1.4239, Learning rate: 0.010000
# Epoch 33/1000, Train Loss: 1.3816, Val Loss: 1.4461, Learning rate: 0.010000
# Epoch 34/1000, Train Loss: 1.3841, Val Loss: 1.4210, Learning rate: 0.010000
# Epoch 35/1000, Train Loss: 1.3851, Val Loss: 1.4506, Learning rate: 0.010000
# Epoch 36/1000, Train Loss: 1.3759, Val Loss: 1.4129, Learning rate: 0.010000
# Epoch 37/1000, Train Loss: 1.3762, Val Loss: 1.4159, Learning rate: 0.010000
# Epoch 38/1000, Train Loss: 1.3576, Val Loss: 1.4364, Learning rate: 0.010000
# Epoch 39/1000, Train Loss: 1.3822, Val Loss: 1.4267, Learning rate: 0.010000
# Epoch 40/1000, Train Loss: 1.3729, Val Loss: 1.4443, Learning rate: 0.010000
# Epoch 41/1000, Train Loss: 1.3681, Val Loss: 1.4151, Learning rate: 0.010000
# Epoch 42/1000, Train Loss: 1.3568, Val Loss: 1.4408, Learning rate: 0.010000
# Epoch 43/1000, Train Loss: 1.3520, Val Loss: 1.4244, Learning rate: 0.010000
# Epoch 44/1000, Train Loss: 1.3683, Val Loss: 1.4337, Learning rate: 0.010000
# Epoch 45/1000, Train Loss: 1.3673, Val Loss: 1.4221, Learning rate: 0.010000
# Epoch 46/1000, Train Loss: 1.3657, Val Loss: 1.4396, Learning rate: 0.010000
# Epoch 47/1000, Train Loss: 1.3709, Val Loss: 1.4280, Learning rate: 0.010000
# Epoch 48/1000, Train Loss: 1.3467, Val Loss: 1.4556, Learning rate: 0.010000
# Epoch 49/1000, Train Loss: 1.3550, Val Loss: 1.4483, Learning rate: 0.010000
# Epoch 50/1000, Train Loss: 1.3652, Val Loss: 1.4313, Learning rate: 0.010000
# Epoch 51/1000, Train Loss: 1.3464, Val Loss: 1.4225, Learning rate: 0.010000
# RandomAgent score: 0.97
# Minimax draw rate: 0.99
# Epoch 52/1000, Train Loss: 1.3518, Val Loss: 1.4144, Learning rate: 0.010000
# Epoch 53/1000, Train Loss: 1.3344, Val Loss: 1.4492, Learning rate: 0.010000
# Epoch 54/1000, Train Loss: 1.3464, Val Loss: 1.4831, Learning rate: 0.010000
# Epoch 55/1000, Train Loss: 1.3451, Val Loss: 1.4130, Learning rate: 0.010000
# Epoch 56/1000, Train Loss: 1.3254, Val Loss: 1.4158, Learning rate: 0.010000
# Epoch 57/1000, Train Loss: 1.3311, Val Loss: 1.4257, Learning rate: 0.010000
# Epoch 58/1000, Train Loss: 1.3440, Val Loss: 1.4356, Learning rate: 0.010000
# Epoch 59/1000, Train Loss: 1.3319, Val Loss: 1.4101, Learning rate: 0.010000
# Epoch 60/1000, Train Loss: 1.3292, Val Loss: 1.4073, Learning rate: 0.010000
# Epoch 61/1000, Train Loss: 1.3302, Val Loss: 1.4454, Learning rate: 0.010000
# Epoch 62/1000, Train Loss: 1.3233, Val Loss: 1.4423, Learning rate: 0.010000
# Epoch 63/1000, Train Loss: 1.3380, Val Loss: 1.4190, Learning rate: 0.010000
# Epoch 64/1000, Train Loss: 1.3363, Val Loss: 1.4100, Learning rate: 0.010000
# Epoch 65/1000, Train Loss: 1.3231, Val Loss: 1.4321, Learning rate: 0.010000
# Epoch 66/1000, Train Loss: 1.3269, Val Loss: 1.4225, Learning rate: 0.010000
# Epoch 67/1000, Train Loss: 1.3201, Val Loss: 1.4760, Learning rate: 0.010000
# Epoch 68/1000, Train Loss: 1.3283, Val Loss: 1.3996, Learning rate: 0.010000
# Epoch 69/1000, Train Loss: 1.3166, Val Loss: 1.4085, Learning rate: 0.010000
# Epoch 70/1000, Train Loss: 1.3144, Val Loss: 1.4083, Learning rate: 0.010000
# Epoch 71/1000, Train Loss: 1.3237, Val Loss: 1.4610, Learning rate: 0.010000
# Epoch 72/1000, Train Loss: 1.3198, Val Loss: 1.4872, Learning rate: 0.010000
# Epoch 73/1000, Train Loss: 1.3312, Val Loss: 1.4309, Learning rate: 0.010000
# Epoch 74/1000, Train Loss: 1.3205, Val Loss: 1.4292, Learning rate: 0.010000
# Epoch 75/1000, Train Loss: 1.3241, Val Loss: 1.4148, Learning rate: 0.010000
# Epoch 76/1000, Train Loss: 1.3198, Val Loss: 1.4234, Learning rate: 0.010000
# Epoch 77/1000, Train Loss: 1.3087, Val Loss: 1.4200, Learning rate: 0.010000
# Epoch 78/1000, Train Loss: 1.3085, Val Loss: 1.4516, Learning rate: 0.010000
# Epoch 79/1000, Train Loss: 1.3110, Val Loss: 1.3983, Learning rate: 0.010000
# Epoch 80/1000, Train Loss: 1.3026, Val Loss: 1.4198, Learning rate: 0.010000
# Epoch 81/1000, Train Loss: 1.3067, Val Loss: 1.4169, Learning rate: 0.010000
# Epoch 82/1000, Train Loss: 1.3182, Val Loss: 1.4081, Learning rate: 0.010000
# Epoch 83/1000, Train Loss: 1.3019, Val Loss: 1.4299, Learning rate: 0.010000
# Epoch 84/1000, Train Loss: 1.3164, Val Loss: 1.3943, Learning rate: 0.010000
# Epoch 85/1000, Train Loss: 1.3120, Val Loss: 1.4019, Learning rate: 0.010000
# Epoch 86/1000, Train Loss: 1.3038, Val Loss: 1.4335, Learning rate: 0.010000
# Epoch 87/1000, Train Loss: 1.3208, Val Loss: 1.4537, Learning rate: 0.010000
# Epoch 88/1000, Train Loss: 1.3319, Val Loss: 1.4067, Learning rate: 0.010000
# Epoch 89/1000, Train Loss: 1.3053, Val Loss: 1.3750, Learning rate: 0.010000
# Epoch 90/1000, Train Loss: 1.2878, Val Loss: 1.4247, Learning rate: 0.010000
# Epoch 91/1000, Train Loss: 1.2873, Val Loss: 1.4249, Learning rate: 0.010000
# Epoch 92/1000, Train Loss: 1.3017, Val Loss: 1.4124, Learning rate: 0.010000
# Epoch 93/1000, Train Loss: 1.2902, Val Loss: 1.4106, Learning rate: 0.010000
# Epoch 94/1000, Train Loss: 1.2856, Val Loss: 1.4313, Learning rate: 0.010000
# Epoch 95/1000, Train Loss: 1.2914, Val Loss: 1.4183, Learning rate: 0.010000
# Epoch 96/1000, Train Loss: 1.3168, Val Loss: 1.4088, Learning rate: 0.010000
# Epoch 97/1000, Train Loss: 1.3054, Val Loss: 1.4213, Learning rate: 0.010000
# Epoch 98/1000, Train Loss: 1.2949, Val Loss: 1.4491, Learning rate: 0.010000
# Epoch 99/1000, Train Loss: 1.2860, Val Loss: 1.4116, Learning rate: 0.010000
# Epoch 100/1000, Train Loss: 1.2825, Val Loss: 1.4141, Learning rate: 0.010000
# Epoch 101/1000, Train Loss: 1.2822, Val Loss: 1.4351, Learning rate: 0.010000
# RandomAgent score: 0.98
# Minimax draw rate: 0.92
# Epoch 102/1000, Train Loss: 1.2803, Val Loss: 1.4276, Learning rate: 0.010000
# Epoch 103/1000, Train Loss: 1.2907, Val Loss: 1.4213, Learning rate: 0.010000
# Epoch 104/1000, Train Loss: 1.2931, Val Loss: 1.4176, Learning rate: 0.010000
# Epoch 105/1000, Train Loss: 1.2918, Val Loss: 1.4201, Learning rate: 0.010000
# Epoch 106/1000, Train Loss: 1.3051, Val Loss: 1.4406, Learning rate: 0.010000
# Epoch 107/1000, Train Loss: 1.3125, Val Loss: 1.4242, Learning rate: 0.010000
# Epoch 108/1000, Train Loss: 1.3118, Val Loss: 1.4090, Learning rate: 0.010000
# Epoch 109/1000, Train Loss: 1.3021, Val Loss: 1.5101, Learning rate: 0.010000
# Epoch 110/1000, Train Loss: 1.2841, Val Loss: 1.4082, Learning rate: 0.010000
# Epoch 111/1000, Train Loss: 1.2780, Val Loss: 1.3973, Learning rate: 0.010000
# Epoch 112/1000, Train Loss: 1.2712, Val Loss: 1.4065, Learning rate: 0.010000
# Epoch 113/1000, Train Loss: 1.2730, Val Loss: 1.4025, Learning rate: 0.010000
# Epoch 114/1000, Train Loss: 1.2825, Val Loss: 1.4322, Learning rate: 0.010000
# Epoch 115/1000, Train Loss: 1.2984, Val Loss: 1.4395, Learning rate: 0.010000
# Epoch 116/1000, Train Loss: 1.2908, Val Loss: 1.4597, Learning rate: 0.010000
# Epoch 117/1000, Train Loss: 1.2747, Val Loss: 1.4187, Learning rate: 0.010000
# Epoch 118/1000, Train Loss: 1.2707, Val Loss: 1.4254, Learning rate: 0.010000
# Epoch 119/1000, Train Loss: 1.2844, Val Loss: 1.4419, Learning rate: 0.010000
# Epoch 120/1000, Train Loss: 1.2784, Val Loss: 1.4561, Learning rate: 0.010000
# Epoch 121/1000, Train Loss: 1.2853, Val Loss: 1.4318, Learning rate: 0.010000
# Epoch 122/1000, Train Loss: 1.2819, Val Loss: 1.4670, Learning rate: 0.010000
# Epoch 123/1000, Train Loss: 1.2820, Val Loss: 1.4036, Learning rate: 0.010000
# Epoch 124/1000, Train Loss: 1.2729, Val Loss: 1.4470, Learning rate: 0.010000
# Epoch 125/1000, Train Loss: 1.2672, Val Loss: 1.4332, Learning rate: 0.010000
# Epoch 126/1000, Train Loss: 1.2674, Val Loss: 1.4215, Learning rate: 0.010000
# Epoch 127/1000, Train Loss: 1.2726, Val Loss: 1.4473, Learning rate: 0.010000
# Epoch 128/1000, Train Loss: 1.2862, Val Loss: 1.4087, Learning rate: 0.010000
# Epoch 129/1000, Train Loss: 1.2713, Val Loss: 1.4727, Learning rate: 0.010000
# Epoch 130/1000, Train Loss: 1.2819, Val Loss: 1.4214, Learning rate: 0.010000
# Epoch 131/1000, Train Loss: 1.2753, Val Loss: 1.4179, Learning rate: 0.010000
# Epoch 132/1000, Train Loss: 1.2807, Val Loss: 1.4307, Learning rate: 0.010000
# Epoch 133/1000, Train Loss: 1.2813, Val Loss: 1.4580, Learning rate: 0.010000
# Epoch 134/1000, Train Loss: 1.2734, Val Loss: 1.3842, Learning rate: 0.010000
# Epoch 135/1000, Train Loss: 1.2757, Val Loss: 1.4230, Learning rate: 0.010000
# Epoch 136/1000, Train Loss: 1.2679, Val Loss: 1.4031, Learning rate: 0.010000
# Epoch 137/1000, Train Loss: 1.2711, Val Loss: 1.4395, Learning rate: 0.010000
# Epoch 138/1000, Train Loss: 1.2950, Val Loss: 1.4442, Learning rate: 0.010000
# Epoch 139/1000, Train Loss: 1.3249, Val Loss: 1.4389, Learning rate: 0.010000
# Epoch 140/1000, Train Loss: 1.3031, Val Loss: 1.4167, Learning rate: 0.010000
# Epoch 141/1000, Train Loss: 1.2881, Val Loss: 1.3982, Learning rate: 0.010000
# Epoch 142/1000, Train Loss: 1.2700, Val Loss: 1.3769, Learning rate: 0.010000
# Epoch 143/1000, Train Loss: 1.2655, Val Loss: 1.3668, Learning rate: 0.010000
# Epoch 144/1000, Train Loss: 1.2658, Val Loss: 1.3890, Learning rate: 0.010000
# Epoch 145/1000, Train Loss: 1.2602, Val Loss: 1.4391, Learning rate: 0.010000
# Epoch 146/1000, Train Loss: 1.2726, Val Loss: 1.4171, Learning rate: 0.010000
# Epoch 147/1000, Train Loss: 1.2521, Val Loss: 1.4086, Learning rate: 0.010000
# Epoch 148/1000, Train Loss: 1.2585, Val Loss: 1.4015, Learning rate: 0.010000
# Epoch 149/1000, Train Loss: 1.2596, Val Loss: 1.4037, Learning rate: 0.010000
# Epoch 150/1000, Train Loss: 1.2517, Val Loss: 1.3965, Learning rate: 0.010000
# Epoch 151/1000, Train Loss: 1.2712, Val Loss: 1.4696, Learning rate: 0.010000
# RandomAgent score: 0.92
# Minimax draw rate: 0.97
# Epoch 152/1000, Train Loss: 1.2815, Val Loss: 1.4268, Learning rate: 0.010000
# Epoch 153/1000, Train Loss: 1.3033, Val Loss: 1.4192, Learning rate: 0.010000
# Epoch 154/1000, Train Loss: 1.2722, Val Loss: 1.4271, Learning rate: 0.010000
# Epoch 155/1000, Train Loss: 1.2645, Val Loss: 1.4371, Learning rate: 0.010000
# Epoch 156/1000, Train Loss: 1.2536, Val Loss: 1.4007, Learning rate: 0.010000
# Epoch 157/1000, Train Loss: 1.2509, Val Loss: 1.4400, Learning rate: 0.010000
# Epoch 158/1000, Train Loss: 1.2482, Val Loss: 1.4365, Learning rate: 0.010000
# Epoch 159/1000, Train Loss: 1.2514, Val Loss: 1.4309, Learning rate: 0.010000
# Epoch 160/1000, Train Loss: 1.2792, Val Loss: 1.3890, Learning rate: 0.010000
# Epoch 161/1000, Train Loss: 1.2853, Val Loss: 1.4438, Learning rate: 0.010000
# Epoch 162/1000, Train Loss: 1.2625, Val Loss: 1.3972, Learning rate: 0.010000
# Epoch 163/1000, Train Loss: 1.2450, Val Loss: 1.4534, Learning rate: 0.010000
# Epoch 164/1000, Train Loss: 1.2811, Val Loss: 1.4138, Learning rate: 0.010000
# Epoch 165/1000, Train Loss: 1.2728, Val Loss: 1.4212, Learning rate: 0.010000
# Epoch 166/1000, Train Loss: 1.2560, Val Loss: 1.3937, Learning rate: 0.010000
# Epoch 167/1000, Train Loss: 1.2647, Val Loss: 1.4137, Learning rate: 0.010000
# Epoch 168/1000, Train Loss: 1.2671, Val Loss: 1.4569, Learning rate: 0.010000
# Epoch 169/1000, Train Loss: 1.2548, Val Loss: 1.4196, Learning rate: 0.010000
# Epoch 170/1000, Train Loss: 1.2558, Val Loss: 1.4132, Learning rate: 0.010000
# Epoch 171/1000, Train Loss: 1.2480, Val Loss: 1.4593, Learning rate: 0.010000
# Epoch 172/1000, Train Loss: 1.2636, Val Loss: 1.4339, Learning rate: 0.010000
# Epoch 173/1000, Train Loss: 1.2731, Val Loss: 1.4291, Learning rate: 0.010000
# Epoch 174/1000, Train Loss: 1.2705, Val Loss: 1.4497, Learning rate: 0.010000
# Epoch 175/1000, Train Loss: 1.2554, Val Loss: 1.4483, Learning rate: 0.010000
# Epoch 176/1000, Train Loss: 1.2460, Val Loss: 1.4063, Learning rate: 0.010000
# Epoch 177/1000, Train Loss: 1.2526, Val Loss: 1.4414, Learning rate: 0.010000
# Epoch 178/1000, Train Loss: 1.2421, Val Loss: 1.4049, Learning rate: 0.010000
# Epoch 179/1000, Train Loss: 1.2502, Val Loss: 1.4111, Learning rate: 0.010000
# Epoch 180/1000, Train Loss: 1.2657, Val Loss: 1.4062, Learning rate: 0.010000
# Epoch 181/1000, Train Loss: 1.2636, Val Loss: 1.4646, Learning rate: 0.010000
# Epoch 182/1000, Train Loss: 1.2597, Val Loss: 1.4008, Learning rate: 0.010000
# Epoch 183/1000, Train Loss: 1.2484, Val Loss: 1.4073, Learning rate: 0.010000
# Epoch 184/1000, Train Loss: 1.2661, Val Loss: 1.3966, Learning rate: 0.010000
# Epoch 185/1000, Train Loss: 1.2695, Val Loss: 1.3918, Learning rate: 0.010000
# Epoch 186/1000, Train Loss: 1.2577, Val Loss: 1.3908, Learning rate: 0.010000
# Epoch 187/1000, Train Loss: 1.2412, Val Loss: 1.4354, Learning rate: 0.010000
# Epoch 188/1000, Train Loss: 1.2588, Val Loss: 1.4907, Learning rate: 0.010000
# Epoch 189/1000, Train Loss: 1.2752, Val Loss: 1.4310, Learning rate: 0.010000
# Epoch 190/1000, Train Loss: 1.2542, Val Loss: 1.5444, Learning rate: 0.010000
# Epoch 191/1000, Train Loss: 1.2721, Val Loss: 1.4156, Learning rate: 0.010000
# Epoch 192/1000, Train Loss: 1.2699, Val Loss: 1.4117, Learning rate: 0.010000
# Epoch 193/1000, Train Loss: 1.2451, Val Loss: 1.4224, Learning rate: 0.010000
# Epoch 194/1000, Train Loss: 1.2609, Val Loss: 1.4169, Learning rate: 0.010000
# Epoch 195/1000, Train Loss: 1.2576, Val Loss: 1.4290, Learning rate: 0.010000
# Epoch 196/1000, Train Loss: 1.2524, Val Loss: 1.4229, Learning rate: 0.010000
# Epoch 197/1000, Train Loss: 1.2676, Val Loss: 1.4629, Learning rate: 0.010000
# Epoch 198/1000, Train Loss: 1.2783, Val Loss: 1.4726, Learning rate: 0.010000
# Epoch 199/1000, Train Loss: 1.2595, Val Loss: 1.3957, Learning rate: 0.010000
# Epoch 200/1000, Train Loss: 1.2565, Val Loss: 1.4556, Learning rate: 0.010000
# Epoch 201/1000, Train Loss: 1.2398, Val Loss: 1.3945, Learning rate: 0.010000
# RandomAgent score: 0.9
# Minimax draw rate: 0.97
# Epoch 202/1000, Train Loss: 1.2393, Val Loss: 1.4637, Learning rate: 0.010000
# Epoch 203/1000, Train Loss: 1.2460, Val Loss: 1.4417, Learning rate: 0.010000
# Epoch 204/1000, Train Loss: 1.2415, Val Loss: 1.4211, Learning rate: 0.010000
# Epoch 205/1000, Train Loss: 1.2386, Val Loss: 1.4044, Learning rate: 0.010000
# Epoch 206/1000, Train Loss: 1.2742, Val Loss: 1.4435, Learning rate: 0.010000
# Epoch 207/1000, Train Loss: 1.2617, Val Loss: 1.3966, Learning rate: 0.010000
# Epoch 208/1000, Train Loss: 1.2565, Val Loss: 1.4165, Learning rate: 0.010000
# Epoch 209/1000, Train Loss: 1.2493, Val Loss: 1.3817, Learning rate: 0.010000
# Epoch 210/1000, Train Loss: 1.2388, Val Loss: 1.4662, Learning rate: 0.010000
# Epoch 211/1000, Train Loss: 1.2580, Val Loss: 1.4395, Learning rate: 0.010000
# Epoch 212/1000, Train Loss: 1.2518, Val Loss: 1.3863, Learning rate: 0.010000
# Epoch 213/1000, Train Loss: 1.2706, Val Loss: 1.3946, Learning rate: 0.010000
# Epoch 214/1000, Train Loss: 1.2498, Val Loss: 1.3792, Learning rate: 0.010000
# Epoch 215/1000, Train Loss: 1.2299, Val Loss: 1.3730, Learning rate: 0.010000
# Epoch 216/1000, Train Loss: 1.2394, Val Loss: 1.4326, Learning rate: 0.010000
# Epoch 217/1000, Train Loss: 1.2447, Val Loss: 1.4158, Learning rate: 0.010000
# Epoch 218/1000, Train Loss: 1.2361, Val Loss: 1.3831, Learning rate: 0.010000
# Epoch 219/1000, Train Loss: 1.2304, Val Loss: 1.4320, Learning rate: 0.010000
# Epoch 220/1000, Train Loss: 1.2401, Val Loss: 1.4543, Learning rate: 0.010000
# Epoch 221/1000, Train Loss: 1.2448, Val Loss: 1.4063, Learning rate: 0.010000
# Epoch 222/1000, Train Loss: 1.2514, Val Loss: 1.4524, Learning rate: 0.010000
# Epoch 223/1000, Train Loss: 1.2513, Val Loss: 1.4550, Learning rate: 0.010000
# Epoch 224/1000, Train Loss: 1.2679, Val Loss: 1.4094, Learning rate: 0.010000
# Epoch 225/1000, Train Loss: 1.2856, Val Loss: 1.3901, Learning rate: 0.010000
# Epoch 226/1000, Train Loss: 1.2811, Val Loss: 1.4093, Learning rate: 0.010000
# Epoch 227/1000, Train Loss: 1.2621, Val Loss: 1.4018, Learning rate: 0.010000
# Epoch 228/1000, Train Loss: 1.2476, Val Loss: 1.4352, Learning rate: 0.010000
# Epoch 229/1000, Train Loss: 1.2535, Val Loss: 1.4166, Learning rate: 0.010000
# Epoch 230/1000, Train Loss: 1.2556, Val Loss: 1.3926, Learning rate: 0.010000
# Epoch 231/1000, Train Loss: 1.2347, Val Loss: 1.5001, Learning rate: 0.010000
# Epoch 232/1000, Train Loss: 1.2405, Val Loss: 1.4467, Learning rate: 0.010000
# Epoch 233/1000, Train Loss: 1.2564, Val Loss: 1.4043, Learning rate: 0.010000
# Epoch 234/1000, Train Loss: 1.2490, Val Loss: 1.4212, Learning rate: 0.010000
# Epoch 235/1000, Train Loss: 1.2535, Val Loss: 1.4009, Learning rate: 0.010000
# Epoch 236/1000, Train Loss: 1.2348, Val Loss: 1.4156, Learning rate: 0.010000
# Epoch 237/1000, Train Loss: 1.2346, Val Loss: 1.4829, Learning rate: 0.010000
# Epoch 238/1000, Train Loss: 1.2464, Val Loss: 1.4225, Learning rate: 0.010000
# Epoch 239/1000, Train Loss: 1.2559, Val Loss: 1.4150, Learning rate: 0.010000
# Epoch 240/1000, Train Loss: 1.2497, Val Loss: 1.4017, Learning rate: 0.010000
# Epoch 241/1000, Train Loss: 1.2396, Val Loss: 1.4081, Learning rate: 0.010000
# Epoch 242/1000, Train Loss: 1.2420, Val Loss: 1.4257, Learning rate: 0.010000
# Epoch 243/1000, Train Loss: 1.2622, Val Loss: 1.3919, Learning rate: 0.010000
# Epoch 244/1000, Train Loss: 1.2456, Val Loss: 1.3817, Learning rate: 0.010000
# Epoch 245/1000, Train Loss: 1.2315, Val Loss: 1.3754, Learning rate: 0.001000
# Epoch 246/1000, Train Loss: 1.2066, Val Loss: 1.3831, Learning rate: 0.001000
# Epoch 247/1000, Train Loss: 1.1913, Val Loss: 1.3935, Learning rate: 0.001000
# Epoch 248/1000, Train Loss: 1.1977, Val Loss: 1.4030, Learning rate: 0.001000
# Epoch 249/1000, Train Loss: 1.1956, Val Loss: 1.4146, Learning rate: 0.001000
# Epoch 250/1000, Train Loss: 1.1871, Val Loss: 1.4191, Learning rate: 0.001000
# Epoch 251/1000, Train Loss: 1.1877, Val Loss: 1.4310, Learning rate: 0.001000
# RandomAgent score: 0.92
# Minimax draw rate: 0.99
# Epoch 252/1000, Train Loss: 1.1837, Val Loss: 1.4360, Learning rate: 0.001000
# Epoch 253/1000, Train Loss: 1.1865, Val Loss: 1.4475, Learning rate: 0.001000
# Epoch 254/1000, Train Loss: 1.1793, Val Loss: 1.4496, Learning rate: 0.001000
# Epoch 255/1000, Train Loss: 1.1850, Val Loss: 1.4530, Learning rate: 0.001000
# Epoch 256/1000, Train Loss: 1.1796, Val Loss: 1.4593, Learning rate: 0.001000
# Epoch 257/1000, Train Loss: 1.1780, Val Loss: 1.4613, Learning rate: 0.001000
# Epoch 258/1000, Train Loss: 1.1807, Val Loss: 1.4679, Learning rate: 0.001000
# Epoch 259/1000, Train Loss: 1.1746, Val Loss: 1.4729, Learning rate: 0.001000
# Epoch 260/1000, Train Loss: 1.1787, Val Loss: 1.4743, Learning rate: 0.001000
# Epoch 261/1000, Train Loss: 1.1737, Val Loss: 1.4798, Learning rate: 0.001000
# Epoch 262/1000, Train Loss: 1.1769, Val Loss: 1.4826, Learning rate: 0.001000
# Epoch 263/1000, Train Loss: 1.1758, Val Loss: 1.4865, Learning rate: 0.001000
# Epoch 264/1000, Train Loss: 1.1804, Val Loss: 1.4904, Learning rate: 0.001000
# Epoch 265/1000, Train Loss: 1.1722, Val Loss: 1.4926, Learning rate: 0.001000
# Epoch 266/1000, Train Loss: 1.1746, Val Loss: 1.5001, Learning rate: 0.001000
# Epoch 267/1000, Train Loss: 1.1868, Val Loss: 1.4934, Learning rate: 0.001000
# Epoch 268/1000, Train Loss: 1.1747, Val Loss: 1.5043, Learning rate: 0.001000
# Epoch 269/1000, Train Loss: 1.1668, Val Loss: 1.5003, Learning rate: 0.001000
# Epoch 270/1000, Train Loss: 1.1743, Val Loss: 1.5056, Learning rate: 0.001000
# Epoch 271/1000, Train Loss: 1.1734, Val Loss: 1.4945, Learning rate: 0.001000
# Epoch 272/1000, Train Loss: 1.1701, Val Loss: 1.5089, Learning rate: 0.001000
# Epoch 273/1000, Train Loss: 1.1731, Val Loss: 1.4979, Learning rate: 0.001000
# Epoch 274/1000, Train Loss: 1.1733, Val Loss: 1.5060, Learning rate: 0.001000
# Epoch 275/1000, Train Loss: 1.1656, Val Loss: 1.5098, Learning rate: 0.001000
# Epoch 276/1000, Train Loss: 1.1695, Val Loss: 1.5182, Learning rate: 0.001000
# Epoch 277/1000, Train Loss: 1.1733, Val Loss: 1.5091, Learning rate: 0.001000
# Epoch 278/1000, Train Loss: 1.1635, Val Loss: 1.5220, Learning rate: 0.001000
# Epoch 279/1000, Train Loss: 1.1687, Val Loss: 1.5046, Learning rate: 0.001000
# Epoch 280/1000, Train Loss: 1.1766, Val Loss: 1.5228, Learning rate: 0.001000
# Epoch 281/1000, Train Loss: 1.1729, Val Loss: 1.5091, Learning rate: 0.001000
# Epoch 282/1000, Train Loss: 1.1675, Val Loss: 1.5288, Learning rate: 0.001000
# Epoch 283/1000, Train Loss: 1.1675, Val Loss: 1.5168, Learning rate: 0.001000
# Epoch 284/1000, Train Loss: 1.1712, Val Loss: 1.5292, Learning rate: 0.001000
# Epoch 285/1000, Train Loss: 1.1659, Val Loss: 1.5206, Learning rate: 0.001000
# Epoch 286/1000, Train Loss: 1.1652, Val Loss: 1.5322, Learning rate: 0.001000
# Epoch 287/1000, Train Loss: 1.1668, Val Loss: 1.5355, Learning rate: 0.001000
# Epoch 288/1000, Train Loss: 1.1636, Val Loss: 1.5434, Learning rate: 0.001000
# Epoch 289/1000, Train Loss: 1.1665, Val Loss: 1.5310, Learning rate: 0.001000
# Epoch 290/1000, Train Loss: 1.1715, Val Loss: 1.5426, Learning rate: 0.001000
# Epoch 291/1000, Train Loss: 1.1751, Val Loss: 1.5038, Learning rate: 0.001000
# Epoch 292/1000, Train Loss: 1.1690, Val Loss: 1.5322, Learning rate: 0.001000
# Epoch 293/1000, Train Loss: 1.1753, Val Loss: 1.5219, Learning rate: 0.001000
# Epoch 294/1000, Train Loss: 1.1696, Val Loss: 1.5160, Learning rate: 0.001000
# Epoch 295/1000, Train Loss: 1.1684, Val Loss: 1.5224, Learning rate: 0.001000
# Epoch 296/1000, Train Loss: 1.1641, Val Loss: 1.5320, Learning rate: 0.001000
# Epoch 297/1000, Train Loss: 1.1688, Val Loss: 1.5200, Learning rate: 0.001000
# Epoch 298/1000, Train Loss: 1.1664, Val Loss: 1.5319, Learning rate: 0.001000
# Epoch 299/1000, Train Loss: 1.1711, Val Loss: 1.5257, Learning rate: 0.001000
# Epoch 300/1000, Train Loss: 1.1631, Val Loss: 1.5442, Learning rate: 0.001000
# Epoch 301/1000, Train Loss: 1.1717, Val Loss: 1.5391, Learning rate: 0.001000
# RandomAgent score: 0.94
# Minimax draw rate: 0.97
# Epoch 302/1000, Train Loss: 1.1682, Val Loss: 1.5438, Learning rate: 0.001000
# Epoch 303/1000, Train Loss: 1.1759, Val Loss: 1.5379, Learning rate: 0.001000
# Epoch 304/1000, Train Loss: 1.1663, Val Loss: 1.5442, Learning rate: 0.001000
# Epoch 305/1000, Train Loss: 1.1633, Val Loss: 1.5274, Learning rate: 0.001000
# Epoch 306/1000, Train Loss: 1.1674, Val Loss: 1.5430, Learning rate: 0.001000
# Epoch 307/1000, Train Loss: 1.1680, Val Loss: 1.5409, Learning rate: 0.001000
# Epoch 308/1000, Train Loss: 1.1718, Val Loss: 1.5169, Learning rate: 0.001000
# Epoch 309/1000, Train Loss: 1.1663, Val Loss: 1.5407, Learning rate: 0.001000
# Epoch 310/1000, Train Loss: 1.1638, Val Loss: 1.5406, Learning rate: 0.001000
# Epoch 311/1000, Train Loss: 1.1687, Val Loss: 1.5523, Learning rate: 0.001000
# Epoch 312/1000, Train Loss: 1.1598, Val Loss: 1.5518, Learning rate: 0.001000
# Epoch 313/1000, Train Loss: 1.1660, Val Loss: 1.5570, Learning rate: 0.001000
# Epoch 314/1000, Train Loss: 1.1675, Val Loss: 1.5599, Learning rate: 0.001000
# Epoch 315/1000, Train Loss: 1.1692, Val Loss: 1.5544, Learning rate: 0.001000
# Epoch 316/1000, Train Loss: 1.1689, Val Loss: 1.5588, Learning rate: 0.001000
# Epoch 317/1000, Train Loss: 1.1624, Val Loss: 1.5434, Learning rate: 0.001000
# Epoch 318/1000, Train Loss: 1.1681, Val Loss: 1.5415, Learning rate: 0.001000
# Epoch 319/1000, Train Loss: 1.1652, Val Loss: 1.5470, Learning rate: 0.001000
# Epoch 320/1000, Train Loss: 1.1667, Val Loss: 1.5315, Learning rate: 0.001000
# Epoch 321/1000, Train Loss: 1.1660, Val Loss: 1.5311, Learning rate: 0.001000
# Epoch 322/1000, Train Loss: 1.1670, Val Loss: 1.5375, Learning rate: 0.001000
# Epoch 323/1000, Train Loss: 1.1690, Val Loss: 1.5204, Learning rate: 0.001000
# Epoch 324/1000, Train Loss: 1.1703, Val Loss: 1.5226, Learning rate: 0.001000
# Epoch 325/1000, Train Loss: 1.1735, Val Loss: 1.5166, Learning rate: 0.001000
# Epoch 326/1000, Train Loss: 1.1627, Val Loss: 1.5318, Learning rate: 0.001000
# Epoch 327/1000, Train Loss: 1.1629, Val Loss: 1.5398, Learning rate: 0.001000
# Epoch 328/1000, Train Loss: 1.1765, Val Loss: 1.5573, Learning rate: 0.001000
# Epoch 329/1000, Train Loss: 1.1634, Val Loss: 1.5444, Learning rate: 0.001000
# Epoch 330/1000, Train Loss: 1.1601, Val Loss: 1.5484, Learning rate: 0.001000
# Epoch 331/1000, Train Loss: 1.1667, Val Loss: 1.5600, Learning rate: 0.001000
# Epoch 332/1000, Train Loss: 1.1655, Val Loss: 1.5677, Learning rate: 0.001000
# Epoch 333/1000, Train Loss: 1.1645, Val Loss: 1.5419, Learning rate: 0.001000
# Epoch 334/1000, Train Loss: 1.1616, Val Loss: 1.5553, Learning rate: 0.001000
# Epoch 335/1000, Train Loss: 1.1685, Val Loss: 1.5335, Learning rate: 0.001000
# Epoch 336/1000, Train Loss: 1.1671, Val Loss: 1.5464, Learning rate: 0.001000
# Epoch 337/1000, Train Loss: 1.1632, Val Loss: 1.5473, Learning rate: 0.001000
# Epoch 338/1000, Train Loss: 1.1669, Val Loss: 1.5618, Learning rate: 0.001000
# Epoch 339/1000, Train Loss: 1.1658, Val Loss: 1.5470, Learning rate: 0.001000
# Epoch 340/1000, Train Loss: 1.1761, Val Loss: 1.5655, Learning rate: 0.001000
# Epoch 341/1000, Train Loss: 1.1589, Val Loss: 1.5466, Learning rate: 0.001000
# Epoch 342/1000, Train Loss: 1.1645, Val Loss: 1.5574, Learning rate: 0.001000
# Epoch 343/1000, Train Loss: 1.1676, Val Loss: 1.5486, Learning rate: 0.001000
# Epoch 344/1000, Train Loss: 1.1621, Val Loss: 1.5506, Learning rate: 0.001000
# Epoch 345/1000, Train Loss: 1.1686, Val Loss: 1.5284, Learning rate: 0.001000
# Epoch 346/1000, Train Loss: 1.1643, Val Loss: 1.5521, Learning rate: 0.001000
# Epoch 347/1000, Train Loss: 1.1711, Val Loss: 1.5451, Learning rate: 0.001000
# Epoch 348/1000, Train Loss: 1.1676, Val Loss: 1.5383, Learning rate: 0.001000
# Epoch 349/1000, Train Loss: 1.1648, Val Loss: 1.5405, Learning rate: 0.001000
# Epoch 350/1000, Train Loss: 1.1668, Val Loss: 1.5341, Learning rate: 0.001000
# Epoch 351/1000, Train Loss: 1.1668, Val Loss: 1.5170, Learning rate: 0.001000
# RandomAgent score: 0.7899999999999999
# Minimax draw rate: 0.83
# Epoch 352/1000, Train Loss: 1.1682, Val Loss: 1.5160, Learning rate: 0.001000
# Epoch 353/1000, Train Loss: 1.1650, Val Loss: 1.5147, Learning rate: 0.001000
# Epoch 354/1000, Train Loss: 1.1602, Val Loss: 1.5035, Learning rate: 0.001000
# Epoch 355/1000, Train Loss: 1.1653, Val Loss: 1.5229, Learning rate: 0.001000
# Epoch 356/1000, Train Loss: 1.1713, Val Loss: 1.5071, Learning rate: 0.001000
# Epoch 357/1000, Train Loss: 1.1662, Val Loss: 1.5156, Learning rate: 0.001000
# Epoch 358/1000, Train Loss: 1.1644, Val Loss: 1.5217, Learning rate: 0.001000
# Epoch 359/1000, Train Loss: 1.1706, Val Loss: 1.4968, Learning rate: 0.001000
# Epoch 360/1000, Train Loss: 1.1664, Val Loss: 1.5324, Learning rate: 0.001000
# Epoch 361/1000, Train Loss: 1.1711, Val Loss: 1.5101, Learning rate: 0.001000
# Epoch 362/1000, Train Loss: 1.1704, Val Loss: 1.5166, Learning rate: 0.001000
# Epoch 363/1000, Train Loss: 1.1682, Val Loss: 1.5242, Learning rate: 0.001000
# Epoch 364/1000, Train Loss: 1.1654, Val Loss: 1.5310, Learning rate: 0.001000
# Epoch 365/1000, Train Loss: 1.1685, Val Loss: 1.5399, Learning rate: 0.001000
# Epoch 366/1000, Train Loss: 1.1618, Val Loss: 1.5527, Learning rate: 0.001000
# Epoch 367/1000, Train Loss: 1.1641, Val Loss: 1.5539, Learning rate: 0.001000
# Epoch 368/1000, Train Loss: 1.1667, Val Loss: 1.5474, Learning rate: 0.001000
# Epoch 369/1000, Train Loss: 1.1714, Val Loss: 1.5175, Learning rate: 0.001000
# Epoch 370/1000, Train Loss: 1.1639, Val Loss: 1.5424, Learning rate: 0.001000
# Epoch 371/1000, Train Loss: 1.1648, Val Loss: 1.5158, Learning rate: 0.001000
# Epoch 372/1000, Train Loss: 1.1699, Val Loss: 1.5627, Learning rate: 0.001000
# Epoch 373/1000, Train Loss: 1.1622, Val Loss: 1.5271, Learning rate: 0.001000
# Epoch 374/1000, Train Loss: 1.1649, Val Loss: 1.5092, Learning rate: 0.001000
# Epoch 375/1000, Train Loss: 1.1686, Val Loss: 1.5392, Learning rate: 0.001000
# Epoch 376/1000, Train Loss: 1.1718, Val Loss: 1.5356, Learning rate: 0.001000
# Epoch 377/1000, Train Loss: 1.1642, Val Loss: 1.5257, Learning rate: 0.001000
# Epoch 378/1000, Train Loss: 1.1722, Val Loss: 1.5338, Learning rate: 0.001000
# Epoch 379/1000, Train Loss: 1.1675, Val Loss: 1.5476, Learning rate: 0.001000
# Epoch 380/1000, Train Loss: 1.1732, Val Loss: 1.5351, Learning rate: 0.001000
# Epoch 381/1000, Train Loss: 1.1631, Val Loss: 1.5144, Learning rate: 0.001000
# Epoch 382/1000, Train Loss: 1.1683, Val Loss: 1.5190, Learning rate: 0.001000
# Epoch 383/1000, Train Loss: 1.1613, Val Loss: 1.5135, Learning rate: 0.001000
# Epoch 384/1000, Train Loss: 1.1681, Val Loss: 1.4978, Learning rate: 0.001000
# Epoch 385/1000, Train Loss: 1.1709, Val Loss: 1.5239, Learning rate: 0.001000
# Epoch 386/1000, Train Loss: 1.1665, Val Loss: 1.5116, Learning rate: 0.001000
# Epoch 387/1000, Train Loss: 1.1726, Val Loss: 1.5204, Learning rate: 0.001000
# Epoch 388/1000, Train Loss: 1.1571, Val Loss: 1.5347, Learning rate: 0.001000
# Epoch 389/1000, Train Loss: 1.1631, Val Loss: 1.5250, Learning rate: 0.001000
# Epoch 390/1000, Train Loss: 1.1627, Val Loss: 1.5423, Learning rate: 0.001000
# Epoch 391/1000, Train Loss: 1.1720, Val Loss: 1.5393, Learning rate: 0.001000
# Epoch 392/1000, Train Loss: 1.1640, Val Loss: 1.5362, Learning rate: 0.001000
# Epoch 393/1000, Train Loss: 1.1600, Val Loss: 1.5528, Learning rate: 0.001000
# Epoch 394/1000, Train Loss: 1.1616, Val Loss: 1.5587, Learning rate: 0.001000
# Epoch 395/1000, Train Loss: 1.1614, Val Loss: 1.5480, Learning rate: 0.001000
# Epoch 396/1000, Train Loss: 1.1724, Val Loss: 1.5501, Learning rate: 0.001000
# Epoch 397/1000, Train Loss: 1.1667, Val Loss: 1.5660, Learning rate: 0.001000
# Epoch 398/1000, Train Loss: 1.1676, Val Loss: 1.5528, Learning rate: 0.001000
# Epoch 399/1000, Train Loss: 1.1604, Val Loss: 1.5623, Learning rate: 0.001000
# Epoch 400/1000, Train Loss: 1.1642, Val Loss: 1.5499, Learning rate: 0.001000
# Epoch 401/1000, Train Loss: 1.1680, Val Loss: 1.5745, Learning rate: 0.001000
# RandomAgent score: 0.83
# Minimax draw rate: 0.83
# Epoch 402/1000, Train Loss: 1.1684, Val Loss: 1.5424, Learning rate: 0.001000
# Epoch 403/1000, Train Loss: 1.1701, Val Loss: 1.5571, Learning rate: 0.001000
# Epoch 404/1000, Train Loss: 1.1671, Val Loss: 1.5445, Learning rate: 0.001000
# Epoch 405/1000, Train Loss: 1.1669, Val Loss: 1.4840, Learning rate: 0.001000
# Epoch 406/1000, Train Loss: 1.1687, Val Loss: 1.4972, Learning rate: 0.001000
# Epoch 407/1000, Train Loss: 1.1678, Val Loss: 1.5274, Learning rate: 0.001000
# Epoch 408/1000, Train Loss: 1.1691, Val Loss: 1.5445, Learning rate: 0.001000
# Epoch 409/1000, Train Loss: 1.1691, Val Loss: 1.5361, Learning rate: 0.001000
# Epoch 410/1000, Train Loss: 1.1682, Val Loss: 1.4982, Learning rate: 0.001000
# Epoch 411/1000, Train Loss: 1.1705, Val Loss: 1.5621, Learning rate: 0.001000
# Epoch 412/1000, Train Loss: 1.1703, Val Loss: 1.5067, Learning rate: 0.001000
# Epoch 413/1000, Train Loss: 1.1707, Val Loss: 1.4907, Learning rate: 0.001000
# Epoch 414/1000, Train Loss: 1.1698, Val Loss: 1.5420, Learning rate: 0.001000
# Epoch 415/1000, Train Loss: 1.1678, Val Loss: 1.5392, Learning rate: 0.001000
# Epoch 416/1000, Train Loss: 1.1701, Val Loss: 1.5339, Learning rate: 0.001000
# Epoch 417/1000, Train Loss: 1.1675, Val Loss: 1.5049, Learning rate: 0.001000
# Epoch 418/1000, Train Loss: 1.1723, Val Loss: 1.5766, Learning rate: 0.001000
# Epoch 419/1000, Train Loss: 1.1694, Val Loss: 1.5232, Learning rate: 0.001000
# Epoch 420/1000, Train Loss: 1.1694, Val Loss: 1.5314, Learning rate: 0.001000
# Epoch 421/1000, Train Loss: 1.1647, Val Loss: 1.5234, Learning rate: 0.001000
# Epoch 422/1000, Train Loss: 1.1724, Val Loss: 1.4727, Learning rate: 0.001000
# Epoch 423/1000, Train Loss: 1.1668, Val Loss: 1.4637, Learning rate: 0.001000
# Epoch 424/1000, Train Loss: 1.1666, Val Loss: 1.5390, Learning rate: 0.001000
# Epoch 425/1000, Train Loss: 1.1713, Val Loss: 1.5221, Learning rate: 0.001000
# Epoch 426/1000, Train Loss: 1.1683, Val Loss: 1.5086, Learning rate: 0.001000
# Epoch 427/1000, Train Loss: 1.1681, Val Loss: 1.5290, Learning rate: 0.001000
# Epoch 428/1000, Train Loss: 1.1735, Val Loss: 1.5473, Learning rate: 0.001000
# Epoch 429/1000, Train Loss: 1.1672, Val Loss: 1.5480, Learning rate: 0.001000
# Epoch 430/1000, Train Loss: 1.1624, Val Loss: 1.5376, Learning rate: 0.001000
# Epoch 431/1000, Train Loss: 1.1624, Val Loss: 1.5555, Learning rate: 0.001000
# Epoch 432/1000, Train Loss: 1.1649, Val Loss: 1.5581, Learning rate: 0.001000
# Epoch 433/1000, Train Loss: 1.1640, Val Loss: 1.5601, Learning rate: 0.001000
# Epoch 434/1000, Train Loss: 1.1642, Val Loss: 1.5832, Learning rate: 0.001000
# Epoch 435/1000, Train Loss: 1.1655, Val Loss: 1.5738, Learning rate: 0.001000
# Epoch 436/1000, Train Loss: 1.1649, Val Loss: 1.5760, Learning rate: 0.001000
# Epoch 437/1000, Train Loss: 1.1635, Val Loss: 1.5563, Learning rate: 0.001000
# Epoch 438/1000, Train Loss: 1.1648, Val Loss: 1.5882, Learning rate: 0.001000
# Epoch 439/1000, Train Loss: 1.1705, Val Loss: 1.5564, Learning rate: 0.001000
# Epoch 440/1000, Train Loss: 1.1708, Val Loss: 1.5913, Learning rate: 0.001000
# Epoch 441/1000, Train Loss: 1.1684, Val Loss: 1.5606, Learning rate: 0.001000
# Epoch 442/1000, Train Loss: 1.1612, Val Loss: 1.5698, Learning rate: 0.001000
# Epoch 443/1000, Train Loss: 1.1654, Val Loss: 1.5722, Learning rate: 0.001000
# Epoch 444/1000, Train Loss: 1.1709, Val Loss: 1.5818, Learning rate: 0.001000
# Epoch 445/1000, Train Loss: 1.1701, Val Loss: 1.5601, Learning rate: 0.001000
# Epoch 446/1000, Train Loss: 1.1685, Val Loss: 1.5648, Learning rate: 0.000100
# Epoch 447/1000, Train Loss: 1.1609, Val Loss: 1.5703, Learning rate: 0.000100
# Epoch 448/1000, Train Loss: 1.1635, Val Loss: 1.5755, Learning rate: 0.000100
# Epoch 449/1000, Train Loss: 1.1639, Val Loss: 1.5806, Learning rate: 0.000100
# Epoch 450/1000, Train Loss: 1.1670, Val Loss: 1.5837, Learning rate: 0.000100
# Epoch 451/1000, Train Loss: 1.1660, Val Loss: 1.5846, Learning rate: 0.000100
# RandomAgent score: 0.95
# Minimax draw rate: 0.95
# Epoch 452/1000, Train Loss: 1.1606, Val Loss: 1.5872, Learning rate: 0.000100
# Epoch 453/1000, Train Loss: 1.1619, Val Loss: 1.5886, Learning rate: 0.000100
# Epoch 454/1000, Train Loss: 1.1611, Val Loss: 1.5904, Learning rate: 0.000100
# Epoch 455/1000, Train Loss: 1.1682, Val Loss: 1.5912, Learning rate: 0.000100
# Epoch 456/1000, Train Loss: 1.1595, Val Loss: 1.5922, Learning rate: 0.000100
# Epoch 457/1000, Train Loss: 1.1700, Val Loss: 1.5936, Learning rate: 0.000100
# Epoch 458/1000, Train Loss: 1.1709, Val Loss: 1.5940, Learning rate: 0.000100
# Epoch 459/1000, Train Loss: 1.1612, Val Loss: 1.5951, Learning rate: 0.000100
# Epoch 460/1000, Train Loss: 1.1611, Val Loss: 1.5958, Learning rate: 0.000100
# Epoch 461/1000, Train Loss: 1.1557, Val Loss: 1.5970, Learning rate: 0.000100
# Epoch 462/1000, Train Loss: 1.1571, Val Loss: 1.5979, Learning rate: 0.000100
# Epoch 463/1000, Train Loss: 1.1604, Val Loss: 1.5989, Learning rate: 0.000100
# Epoch 464/1000, Train Loss: 1.1661, Val Loss: 1.5995, Learning rate: 0.000100
# Epoch 465/1000, Train Loss: 1.1703, Val Loss: 1.6000, Learning rate: 0.000100
# Epoch 466/1000, Train Loss: 1.1593, Val Loss: 1.6009, Learning rate: 0.000100
# Epoch 467/1000, Train Loss: 1.1631, Val Loss: 1.6018, Learning rate: 0.000100
# Epoch 468/1000, Train Loss: 1.1650, Val Loss: 1.6030, Learning rate: 0.000100
# Epoch 469/1000, Train Loss: 1.1679, Val Loss: 1.6032, Learning rate: 0.000100
# Epoch 470/1000, Train Loss: 1.1698, Val Loss: 1.6040, Learning rate: 0.000100
# Epoch 471/1000, Train Loss: 1.1573, Val Loss: 1.6043, Learning rate: 0.000100
# Epoch 472/1000, Train Loss: 1.1646, Val Loss: 1.6058, Learning rate: 0.000100
# Epoch 473/1000, Train Loss: 1.1605, Val Loss: 1.6061, Learning rate: 0.000100
# Epoch 474/1000, Train Loss: 1.1685, Val Loss: 1.6066, Learning rate: 0.000100
# Epoch 475/1000, Train Loss: 1.1689, Val Loss: 1.6074, Learning rate: 0.000100
# Epoch 476/1000, Train Loss: 1.1631, Val Loss: 1.6074, Learning rate: 0.000100
# Epoch 477/1000, Train Loss: 1.1721, Val Loss: 1.6071, Learning rate: 0.000100
# Epoch 478/1000, Train Loss: 1.1574, Val Loss: 1.6074, Learning rate: 0.000100
# Epoch 479/1000, Train Loss: 1.1697, Val Loss: 1.6074, Learning rate: 0.000100
# Epoch 480/1000, Train Loss: 1.1652, Val Loss: 1.6077, Learning rate: 0.000100
# Epoch 481/1000, Train Loss: 1.1668, Val Loss: 1.6078, Learning rate: 0.000100
# Epoch 482/1000, Train Loss: 1.1632, Val Loss: 1.6083, Learning rate: 0.000100
# Epoch 483/1000, Train Loss: 1.1667, Val Loss: 1.6079, Learning rate: 0.000100
# Epoch 484/1000, Train Loss: 1.1653, Val Loss: 1.6071, Learning rate: 0.000100
# Epoch 485/1000, Train Loss: 1.1603, Val Loss: 1.6074, Learning rate: 0.000100
# Epoch 486/1000, Train Loss: 1.1625, Val Loss: 1.6077, Learning rate: 0.000100
# Epoch 487/1000, Train Loss: 1.1672, Val Loss: 1.6078, Learning rate: 0.000100
# Epoch 488/1000, Train Loss: 1.1628, Val Loss: 1.6084, Learning rate: 0.000100
# Epoch 489/1000, Train Loss: 1.1599, Val Loss: 1.6085, Learning rate: 0.000100
# Epoch 490/1000, Train Loss: 1.1692, Val Loss: 1.6087, Learning rate: 0.000100
# Epoch 491/1000, Train Loss: 1.1653, Val Loss: 1.6080, Learning rate: 0.000100
# Epoch 492/1000, Train Loss: 1.1682, Val Loss: 1.6089, Learning rate: 0.000100
# Epoch 493/1000, Train Loss: 1.1615, Val Loss: 1.6088, Learning rate: 0.000100
# Epoch 494/1000, Train Loss: 1.1649, Val Loss: 1.6084, Learning rate: 0.000100
# Epoch 495/1000, Train Loss: 1.1648, Val Loss: 1.6085, Learning rate: 0.000100
# Epoch 496/1000, Train Loss: 1.1704, Val Loss: 1.6082, Learning rate: 0.000100
# Epoch 497/1000, Train Loss: 1.1638, Val Loss: 1.6078, Learning rate: 0.000100
# Epoch 498/1000, Train Loss: 1.1641, Val Loss: 1.6082, Learning rate: 0.000100
# Epoch 499/1000, Train Loss: 1.1598, Val Loss: 1.6090, Learning rate: 0.000100
# Epoch 500/1000, Train Loss: 1.1620, Val Loss: 1.6088, Learning rate: 0.000100
# Epoch 501/1000, Train Loss: 1.1676, Val Loss: 1.6083, Learning rate: 0.000100
# RandomAgent score: 0.85
# Minimax draw rate: 0.87
# Epoch 502/1000, Train Loss: 1.1582, Val Loss: 1.6093, Learning rate: 0.000100
# Epoch 503/1000, Train Loss: 1.1543, Val Loss: 1.6085, Learning rate: 0.000100
# Epoch 504/1000, Train Loss: 1.1608, Val Loss: 1.6086, Learning rate: 0.000100
# Epoch 505/1000, Train Loss: 1.1705, Val Loss: 1.6092, Learning rate: 0.000100
# Epoch 506/1000, Train Loss: 1.1611, Val Loss: 1.6089, Learning rate: 0.000100
# Epoch 507/1000, Train Loss: 1.1672, Val Loss: 1.6089, Learning rate: 0.000100
# Epoch 508/1000, Train Loss: 1.1663, Val Loss: 1.6092, Learning rate: 0.000100
# Epoch 509/1000, Train Loss: 1.1614, Val Loss: 1.6093, Learning rate: 0.000100
# Epoch 510/1000, Train Loss: 1.1659, Val Loss: 1.6096, Learning rate: 0.000100
# Epoch 511/1000, Train Loss: 1.1623, Val Loss: 1.6099, Learning rate: 0.000100
# Epoch 512/1000, Train Loss: 1.1615, Val Loss: 1.6100, Learning rate: 0.000100
# Epoch 513/1000, Train Loss: 1.1697, Val Loss: 1.6093, Learning rate: 0.000100
# Epoch 514/1000, Train Loss: 1.1654, Val Loss: 1.6099, Learning rate: 0.000100
# Epoch 515/1000, Train Loss: 1.1619, Val Loss: 1.6091, Learning rate: 0.000100
# Epoch 516/1000, Train Loss: 1.1679, Val Loss: 1.6099, Learning rate: 0.000100
# Epoch 517/1000, Train Loss: 1.1643, Val Loss: 1.6105, Learning rate: 0.000100
# Epoch 518/1000, Train Loss: 1.1728, Val Loss: 1.6103, Learning rate: 0.000100
# Epoch 519/1000, Train Loss: 1.1593, Val Loss: 1.6103, Learning rate: 0.000100
# Epoch 520/1000, Train Loss: 1.1646, Val Loss: 1.6099, Learning rate: 0.000100
# Epoch 521/1000, Train Loss: 1.1654, Val Loss: 1.6099, Learning rate: 0.000100
# Epoch 522/1000, Train Loss: 1.1633, Val Loss: 1.6104, Learning rate: 0.000100
# Epoch 523/1000, Train Loss: 1.1640, Val Loss: 1.6117, Learning rate: 0.000100
# Epoch 524/1000, Train Loss: 1.1731, Val Loss: 1.6102, Learning rate: 0.000100
# Epoch 525/1000, Train Loss: 1.1621, Val Loss: 1.6107, Learning rate: 0.000100
# Epoch 526/1000, Train Loss: 1.1659, Val Loss: 1.6106, Learning rate: 0.000100
# Epoch 527/1000, Train Loss: 1.1635, Val Loss: 1.6107, Learning rate: 0.000100
# Epoch 528/1000, Train Loss: 1.1584, Val Loss: 1.6108, Learning rate: 0.000100
# Epoch 529/1000, Train Loss: 1.1517, Val Loss: 1.6102, Learning rate: 0.000100
# Epoch 530/1000, Train Loss: 1.1713, Val Loss: 1.6106, Learning rate: 0.000100
# Epoch 531/1000, Train Loss: 1.1644, Val Loss: 1.6114, Learning rate: 0.000100
# Epoch 532/1000, Train Loss: 1.1590, Val Loss: 1.6118, Learning rate: 0.000100
# Epoch 533/1000, Train Loss: 1.1665, Val Loss: 1.6111, Learning rate: 0.000100
# Epoch 534/1000, Train Loss: 1.1645, Val Loss: 1.6123, Learning rate: 0.000100
# Epoch 535/1000, Train Loss: 1.1630, Val Loss: 1.6122, Learning rate: 0.000100
# Epoch 536/1000, Train Loss: 1.1613, Val Loss: 1.6117, Learning rate: 0.000100
# Epoch 537/1000, Train Loss: 1.1612, Val Loss: 1.6126, Learning rate: 0.000100
# Epoch 538/1000, Train Loss: 1.1691, Val Loss: 1.6124, Learning rate: 0.000100
# Epoch 539/1000, Train Loss: 1.1584, Val Loss: 1.6133, Learning rate: 0.000100
# Epoch 540/1000, Train Loss: 1.1641, Val Loss: 1.6123, Learning rate: 0.000100
# Epoch 541/1000, Train Loss: 1.1663, Val Loss: 1.6144, Learning rate: 0.000100
# Epoch 542/1000, Train Loss: 1.1663, Val Loss: 1.6132, Learning rate: 0.000100
# Epoch 543/1000, Train Loss: 1.1673, Val Loss: 1.6125, Learning rate: 0.000100
# Epoch 544/1000, Train Loss: 1.1602, Val Loss: 1.6121, Learning rate: 0.000100
# Epoch 545/1000, Train Loss: 1.1685, Val Loss: 1.6130, Learning rate: 0.000100
# Epoch 546/1000, Train Loss: 1.1660, Val Loss: 1.6132, Learning rate: 0.000100
# Epoch 547/1000, Train Loss: 1.1629, Val Loss: 1.6133, Learning rate: 0.000100
# Epoch 548/1000, Train Loss: 1.1611, Val Loss: 1.6136, Learning rate: 0.000100
# Epoch 549/1000, Train Loss: 1.1591, Val Loss: 1.6146, Learning rate: 0.000100
# Epoch 550/1000, Train Loss: 1.1656, Val Loss: 1.6135, Learning rate: 0.000100
# Epoch 551/1000, Train Loss: 1.1636, Val Loss: 1.6151, Learning rate: 0.000100
# RandomAgent score: 0.86
# Minimax draw rate: 0.86
# Epoch 552/1000, Train Loss: 1.1647, Val Loss: 1.6139, Learning rate: 0.000100
# Epoch 553/1000, Train Loss: 1.1629, Val Loss: 1.6142, Learning rate: 0.000100
# Epoch 554/1000, Train Loss: 1.1692, Val Loss: 1.6138, Learning rate: 0.000100
# Epoch 555/1000, Train Loss: 1.1571, Val Loss: 1.6127, Learning rate: 0.000100
# Epoch 556/1000, Train Loss: 1.1638, Val Loss: 1.6152, Learning rate: 0.000100
# Epoch 557/1000, Train Loss: 1.1618, Val Loss: 1.6149, Learning rate: 0.000100
# Epoch 558/1000, Train Loss: 1.1687, Val Loss: 1.6153, Learning rate: 0.000100
# Epoch 559/1000, Train Loss: 1.1618, Val Loss: 1.6168, Learning rate: 0.000100
# Epoch 560/1000, Train Loss: 1.1596, Val Loss: 1.6150, Learning rate: 0.000100
# Epoch 561/1000, Train Loss: 1.1590, Val Loss: 1.6153, Learning rate: 0.000100
# Epoch 562/1000, Train Loss: 1.1648, Val Loss: 1.6164, Learning rate: 0.000100
# Epoch 563/1000, Train Loss: 1.1676, Val Loss: 1.6145, Learning rate: 0.000100
# Epoch 564/1000, Train Loss: 1.1654, Val Loss: 1.6177, Learning rate: 0.000100
# Epoch 565/1000, Train Loss: 1.1598, Val Loss: 1.6182, Learning rate: 0.000100
# Epoch 566/1000, Train Loss: 1.1654, Val Loss: 1.6160, Learning rate: 0.000100
# Epoch 567/1000, Train Loss: 1.1630, Val Loss: 1.6177, Learning rate: 0.000100
# Epoch 568/1000, Train Loss: 1.1637, Val Loss: 1.6167, Learning rate: 0.000100
# Epoch 569/1000, Train Loss: 1.1629, Val Loss: 1.6166, Learning rate: 0.000100
# Epoch 570/1000, Train Loss: 1.1583, Val Loss: 1.6188, Learning rate: 0.000100
# Epoch 571/1000, Train Loss: 1.1649, Val Loss: 1.6172, Learning rate: 0.000100
# Epoch 572/1000, Train Loss: 1.1675, Val Loss: 1.6196, Learning rate: 0.000100
# Epoch 573/1000, Train Loss: 1.1681, Val Loss: 1.6168, Learning rate: 0.000100
# Epoch 574/1000, Train Loss: 1.1649, Val Loss: 1.6209, Learning rate: 0.000100
# Epoch 575/1000, Train Loss: 1.1632, Val Loss: 1.6195, Learning rate: 0.000100
# Epoch 576/1000, Train Loss: 1.1685, Val Loss: 1.6223, Learning rate: 0.000100
# ...
# Epoch 799/1000, Train Loss: 1.1647, Val Loss: 1.6592, Learning rate: 0.000010
# Epoch 800/1000, Train Loss: 1.1644, Val Loss: 1.6591, Learning rate: 0.000010
# Epoch 801/1000, Train Loss: 1.1599, Val Loss: 1.6595, Learning rate: 0.000010
# RandomAgent score: 0.86
# Minimax draw rate: 0.78
# Epoch 802/1000, Train Loss: 1.1746, Val Loss: 1.6593, Learning rate: 0.000010
# Epoch 803/1000, Train Loss: 1.1577, Val Loss: 1.6593, Learning rate: 0.000010
# Epoch 804/1000, Train Loss: 1.1573, Val Loss: 1.6597, Learning rate: 0.000010
# Epoch 805/1000, Train Loss: 1.1614, Val Loss: 1.6596, Learning rate: 0.000010
# Epoch 806/1000, Train Loss: 1.1628, Val Loss: 1.6599, Learning rate: 0.000010
# Epoch 807/1000, Train Loss: 1.1657, Val Loss: 1.6601, Learning rate: 0.000010
# Epoch 808/1000, Train Loss: 1.1647, Val Loss: 1.6602, Learning rate: 0.000010
# Epoch 809/1000, Train Loss: 1.1646, Val Loss: 1.6601, Learning rate: 0.000010
# Epoch 810/1000, Train Loss: 1.1665, Val Loss: 1.6602, Learning rate: 0.000010
# Epoch 811/1000, Train Loss: 1.1600, Val Loss: 1.6602, Learning rate: 0.000010
# Epoch 812/1000, Train Loss: 1.1724, Val Loss: 1.6605, Learning rate: 0.000010
# Epoch 813/1000, Train Loss: 1.1560, Val Loss: 1.6608, Learning rate: 0.000010
# Epoch 814/1000, Train Loss: 1.1637, Val Loss: 1.6611, Learning rate: 0.000010
# Epoch 815/1000, Train Loss: 1.1610, Val Loss: 1.6604, Learning rate: 0.000010
# Epoch 816/1000, Train Loss: 1.1672, Val Loss: 1.6614, Learning rate: 0.000010
# Epoch 817/1000, Train Loss: 1.1614, Val Loss: 1.6607, Learning rate: 0.000010
# Epoch 818/1000, Train Loss: 1.1610, Val Loss: 1.6610, Learning rate: 0.000010
# Epoch 819/1000, Train Loss: 1.1675, Val Loss: 1.6614, Learning rate: 0.000010
# Epoch 820/1000, Train Loss: 1.1625, Val Loss: 1.6616, Learning rate: 0.000010
# Epoch 821/1000, Train Loss: 1.1568, Val Loss: 1.6614, Learning rate: 0.000010
# Epoch 822/1000, Train Loss: 1.1629, Val Loss: 1.6619, Learning rate: 0.000010
# Epoch 823/1000, Train Loss: 1.1587, Val Loss: 1.6618, Learning rate: 0.000010
# Epoch 824/1000, Train Loss: 1.1656, Val Loss: 1.6621, Learning rate: 0.000010
# Epoch 825/1000, Train Loss: 1.1637, Val Loss: 1.6620, Learning rate: 0.000010
# Epoch 826/1000, Train Loss: 1.1643, Val Loss: 1.6622, Learning rate: 0.000010
# Epoch 827/1000, Train Loss: 1.1644, Val Loss: 1.6625, Learning rate: 0.000010
# Epoch 828/1000, Train Loss: 1.1553, Val Loss: 1.6625, Learning rate: 0.000010
# Epoch 829/1000, Train Loss: 1.1618, Val Loss: 1.6625, Learning rate: 0.000010
# Epoch 830/1000, Train Loss: 1.1557, Val Loss: 1.6619, Learning rate: 0.000010
# Epoch 831/1000, Train Loss: 1.1676, Val Loss: 1.6626, Learning rate: 0.000010
# Epoch 832/1000, Train Loss: 1.1618, Val Loss: 1.6627, Learning rate: 0.000010
# Epoch 833/1000, Train Loss: 1.1564, Val Loss: 1.6631, Learning rate: 0.000010
# Epoch 834/1000, Train Loss: 1.1601, Val Loss: 1.6631, Learning rate: 0.000010
# Epoch 835/1000, Train Loss: 1.1592, Val Loss: 1.6633, Learning rate: 0.000010
# Epoch 836/1000, Train Loss: 1.1649, Val Loss: 1.6634, Learning rate: 0.000010
# Epoch 837/1000, Train Loss: 1.1600, Val Loss: 1.6628, Learning rate: 0.000010
# Epoch 838/1000, Train Loss: 1.1572, Val Loss: 1.6631, Learning rate: 0.000010
# Epoch 839/1000, Train Loss: 1.1621, Val Loss: 1.6634, Learning rate: 0.000010
# Epoch 840/1000, Train Loss: 1.1634, Val Loss: 1.6636, Learning rate: 0.000010
# Epoch 841/1000, Train Loss: 1.1594, Val Loss: 1.6637, Learning rate: 0.000010
# Epoch 842/1000, Train Loss: 1.1615, Val Loss: 1.6638, Learning rate: 0.000010
# Epoch 843/1000, Train Loss: 1.1609, Val Loss: 1.6636, Learning rate: 0.000010
# Epoch 844/1000, Train Loss: 1.1689, Val Loss: 1.6645, Learning rate: 0.000010
# Epoch 845/1000, Train Loss: 1.1693, Val Loss: 1.6642, Learning rate: 0.000010
# Epoch 846/1000, Train Loss: 1.1666, Val Loss: 1.6638, Learning rate: 0.000010
# Epoch 847/1000, Train Loss: 1.1696, Val Loss: 1.6644, Learning rate: 0.000010
# Epoch 848/1000, Train Loss: 1.1678, Val Loss: 1.6644, Learning rate: 0.000001
# Epoch 849/1000, Train Loss: 1.1639, Val Loss: 1.6643, Learning rate: 0.000001
# Epoch 850/1000, Train Loss: 1.1646, Val Loss: 1.6643, Learning rate: 0.000001
# Epoch 851/1000, Train Loss: 1.1634, Val Loss: 1.6643, Learning rate: 0.000001
# RandomAgent score: 0.85
# Minimax draw rate: 0.84
# Epoch 852/1000, Train Loss: 1.1655, Val Loss: 1.6643, Learning rate: 0.000001
# Epoch 853/1000, Train Loss: 1.1598, Val Loss: 1.6644, Learning rate: 0.000001
# Epoch 854/1000, Train Loss: 1.1632, Val Loss: 1.6645, Learning rate: 0.000001
# Epoch 855/1000, Train Loss: 1.1546, Val Loss: 1.6645, Learning rate: 0.000001
# Epoch 856/1000, Train Loss: 1.1633, Val Loss: 1.6645, Learning rate: 0.000001
# Epoch 857/1000, Train Loss: 1.1668, Val Loss: 1.6645, Learning rate: 0.000001
# Epoch 858/1000, Train Loss: 1.1626, Val Loss: 1.6644, Learning rate: 0.000001
# Epoch 859/1000, Train Loss: 1.1652, Val Loss: 1.6645, Learning rate: 0.000001
# Epoch 860/1000, Train Loss: 1.1614, Val Loss: 1.6645, Learning rate: 0.000001
# Epoch 861/1000, Train Loss: 1.1571, Val Loss: 1.6646, Learning rate: 0.000001
# Epoch 862/1000, Train Loss: 1.1690, Val Loss: 1.6646, Learning rate: 0.000001
# Epoch 863/1000, Train Loss: 1.1618, Val Loss: 1.6646, Learning rate: 0.000001
# Epoch 864/1000, Train Loss: 1.1618, Val Loss: 1.6646, Learning rate: 0.000001
# Epoch 865/1000, Train Loss: 1.1594, Val Loss: 1.6646, Learning rate: 0.000001
# Epoch 866/1000, Train Loss: 1.1655, Val Loss: 1.6646, Learning rate: 0.000001
# Epoch 867/1000, Train Loss: 1.1662, Val Loss: 1.6646, Learning rate: 0.000001
# Epoch 868/1000, Train Loss: 1.1662, Val Loss: 1.6646, Learning rate: 0.000001
# Epoch 869/1000, Train Loss: 1.1627, Val Loss: 1.6646, Learning rate: 0.000001
# Epoch 870/1000, Train Loss: 1.1660, Val Loss: 1.6647, Learning rate: 0.000001
# Epoch 871/1000, Train Loss: 1.1712, Val Loss: 1.6647, Learning rate: 0.000001
# Epoch 872/1000, Train Loss: 1.1632, Val Loss: 1.6645, Learning rate: 0.000001
# Epoch 873/1000, Train Loss: 1.1661, Val Loss: 1.6646, Learning rate: 0.000001
# Epoch 874/1000, Train Loss: 1.1640, Val Loss: 1.6646, Learning rate: 0.000001
# Epoch 875/1000, Train Loss: 1.1616, Val Loss: 1.6646, Learning rate: 0.000001
# Epoch 876/1000, Train Loss: 1.1651, Val Loss: 1.6647, Learning rate: 0.000001
# Epoch 877/1000, Train Loss: 1.1601, Val Loss: 1.6647, Learning rate: 0.000001
# Epoch 878/1000, Train Loss: 1.1605, Val Loss: 1.6647, Learning rate: 0.000001
# Epoch 879/1000, Train Loss: 1.1636, Val Loss: 1.6647, Learning rate: 0.000001
# Epoch 880/1000, Train Loss: 1.1618, Val Loss: 1.6647, Learning rate: 0.000001
# Epoch 881/1000, Train Loss: 1.1603, Val Loss: 1.6648, Learning rate: 0.000001
# Epoch 882/1000, Train Loss: 1.1597, Val Loss: 1.6647, Learning rate: 0.000001
# Epoch 883/1000, Train Loss: 1.1650, Val Loss: 1.6648, Learning rate: 0.000001
# Epoch 884/1000, Train Loss: 1.1673, Val Loss: 1.6648, Learning rate: 0.000001
# Epoch 885/1000, Train Loss: 1.1653, Val Loss: 1.6648, Learning rate: 0.000001
# Epoch 886/1000, Train Loss: 1.1624, Val Loss: 1.6647, Learning rate: 0.000001
# Epoch 887/1000, Train Loss: 1.1589, Val Loss: 1.6648, Learning rate: 0.000001
# Epoch 888/1000, Train Loss: 1.1642, Val Loss: 1.6648, Learning rate: 0.000001
# Epoch 889/1000, Train Loss: 1.1649, Val Loss: 1.6648, Learning rate: 0.000001
# Epoch 890/1000, Train Loss: 1.1561, Val Loss: 1.6648, Learning rate: 0.000001
# Epoch 891/1000, Train Loss: 1.1613, Val Loss: 1.6648, Learning rate: 0.000001
# Epoch 892/1000, Train Loss: 1.1663, Val Loss: 1.6649, Learning rate: 0.000001
# Epoch 893/1000, Train Loss: 1.1672, Val Loss: 1.6649, Learning rate: 0.000001
# Epoch 894/1000, Train Loss: 1.1615, Val Loss: 1.6649, Learning rate: 0.000001
# Epoch 895/1000, Train Loss: 1.1597, Val Loss: 1.6650, Learning rate: 0.000001
# Epoch 896/1000, Train Loss: 1.1661, Val Loss: 1.6649, Learning rate: 0.000001
# Epoch 897/1000, Train Loss: 1.1563, Val Loss: 1.6650, Learning rate: 0.000001
# Epoch 898/1000, Train Loss: 1.1652, Val Loss: 1.6649, Learning rate: 0.000001
# Epoch 899/1000, Train Loss: 1.1566, Val Loss: 1.6649, Learning rate: 0.000001
# Epoch 900/1000, Train Loss: 1.1627, Val Loss: 1.6649, Learning rate: 0.000001
# Epoch 901/1000, Train Loss: 1.1647, Val Loss: 1.6650, Learning rate: 0.000001
# RandomAgent score: 0.88
# Minimax draw rate: 0.8
# Epoch 902/1000, Train Loss: 1.1659, Val Loss: 1.6650, Learning rate: 0.000001
# Epoch 903/1000, Train Loss: 1.1623, Val Loss: 1.6649, Learning rate: 0.000001
# Epoch 904/1000, Train Loss: 1.1655, Val Loss: 1.6649, Learning rate: 0.000001
# Epoch 905/1000, Train Loss: 1.1613, Val Loss: 1.6650, Learning rate: 0.000001
# Epoch 906/1000, Train Loss: 1.1570, Val Loss: 1.6650, Learning rate: 0.000001
# Epoch 907/1000, Train Loss: 1.1658, Val Loss: 1.6650, Learning rate: 0.000001
# Epoch 908/1000, Train Loss: 1.1629, Val Loss: 1.6650, Learning rate: 0.000001
# Epoch 909/1000, Train Loss: 1.1614, Val Loss: 1.6650, Learning rate: 0.000001
# Epoch 910/1000, Train Loss: 1.1640, Val Loss: 1.6650, Learning rate: 0.000001
# Epoch 911/1000, Train Loss: 1.1555, Val Loss: 1.6650, Learning rate: 0.000001
# Epoch 912/1000, Train Loss: 1.1640, Val Loss: 1.6650, Learning rate: 0.000001
# Epoch 913/1000, Train Loss: 1.1665, Val Loss: 1.6650, Learning rate: 0.000001
# Epoch 914/1000, Train Loss: 1.1595, Val Loss: 1.6651, Learning rate: 0.000001
# Epoch 915/1000, Train Loss: 1.1602, Val Loss: 1.6651, Learning rate: 0.000001
# Epoch 916/1000, Train Loss: 1.1649, Val Loss: 1.6651, Learning rate: 0.000001
# Epoch 917/1000, Train Loss: 1.1709, Val Loss: 1.6651, Learning rate: 0.000001
# Epoch 918/1000, Train Loss: 1.1623, Val Loss: 1.6653, Learning rate: 0.000001
# Epoch 919/1000, Train Loss: 1.1701, Val Loss: 1.6652, Learning rate: 0.000001
# Epoch 920/1000, Train Loss: 1.1658, Val Loss: 1.6652, Learning rate: 0.000001
# Epoch 921/1000, Train Loss: 1.1581, Val Loss: 1.6652, Learning rate: 0.000001
# Epoch 922/1000, Train Loss: 1.1699, Val Loss: 1.6652, Learning rate: 0.000001
# Epoch 923/1000, Train Loss: 1.1606, Val Loss: 1.6653, Learning rate: 0.000001
# Epoch 924/1000, Train Loss: 1.1562, Val Loss: 1.6653, Learning rate: 0.000001
# Epoch 925/1000, Train Loss: 1.1672, Val Loss: 1.6653, Learning rate: 0.000001
# Epoch 926/1000, Train Loss: 1.1611, Val Loss: 1.6653, Learning rate: 0.000001
# Epoch 927/1000, Train Loss: 1.1578, Val Loss: 1.6652, Learning rate: 0.000001
# Epoch 928/1000, Train Loss: 1.1641, Val Loss: 1.6652, Learning rate: 0.000001
# Epoch 929/1000, Train Loss: 1.1592, Val Loss: 1.6653, Learning rate: 0.000001
# Epoch 930/1000, Train Loss: 1.1639, Val Loss: 1.6653, Learning rate: 0.000001
# Epoch 931/1000, Train Loss: 1.1676, Val Loss: 1.6653, Learning rate: 0.000001
# Epoch 932/1000, Train Loss: 1.1621, Val Loss: 1.6653, Learning rate: 0.000001
# Epoch 933/1000, Train Loss: 1.1660, Val Loss: 1.6652, Learning rate: 0.000001
# Epoch 934/1000, Train Loss: 1.1610, Val Loss: 1.6654, Learning rate: 0.000001
# Epoch 935/1000, Train Loss: 1.1628, Val Loss: 1.6654, Learning rate: 0.000001
# Epoch 936/1000, Train Loss: 1.1646, Val Loss: 1.6654, Learning rate: 0.000001
# Epoch 937/1000, Train Loss: 1.1628, Val Loss: 1.6654, Learning rate: 0.000001
# Epoch 938/1000, Train Loss: 1.1691, Val Loss: 1.6654, Learning rate: 0.000001
# Epoch 939/1000, Train Loss: 1.1584, Val Loss: 1.6655, Learning rate: 0.000001
# Epoch 940/1000, Train Loss: 1.1670, Val Loss: 1.6655, Learning rate: 0.000001
# Epoch 941/1000, Train Loss: 1.1623, Val Loss: 1.6655, Learning rate: 0.000001
# Epoch 942/1000, Train Loss: 1.1564, Val Loss: 1.6655, Learning rate: 0.000001
# Epoch 943/1000, Train Loss: 1.1648, Val Loss: 1.6656, Learning rate: 0.000001
# Epoch 944/1000, Train Loss: 1.1590, Val Loss: 1.6655, Learning rate: 0.000001
# Epoch 945/1000, Train Loss: 1.1628, Val Loss: 1.6655, Learning rate: 0.000001
# Epoch 946/1000, Train Loss: 1.1578, Val Loss: 1.6655, Learning rate: 0.000001
# Epoch 947/1000, Train Loss: 1.1645, Val Loss: 1.6655, Learning rate: 0.000001
# Epoch 948/1000, Train Loss: 1.1637, Val Loss: 1.6656, Learning rate: 0.000001
# Epoch 949/1000, Train Loss: 1.1632, Val Loss: 1.6656, Learning rate: 0.000001
# Epoch 950/1000, Train Loss: 1.1660, Val Loss: 1.6656, Learning rate: 0.000001
# Epoch 951/1000, Train Loss: 1.1635, Val Loss: 1.6657, Learning rate: 0.000001
# RandomAgent score: 0.83
# Minimax draw rate: 0.77
# Epoch 952/1000, Train Loss: 1.1603, Val Loss: 1.6655, Learning rate: 0.000001
# Epoch 953/1000, Train Loss: 1.1628, Val Loss: 1.6657, Learning rate: 0.000001
# Epoch 954/1000, Train Loss: 1.1621, Val Loss: 1.6656, Learning rate: 0.000001
# Epoch 955/1000, Train Loss: 1.1651, Val Loss: 1.6656, Learning rate: 0.000001
# Epoch 956/1000, Train Loss: 1.1578, Val Loss: 1.6656, Learning rate: 0.000001
# Epoch 957/1000, Train Loss: 1.1542, Val Loss: 1.6658, Learning rate: 0.000001
# Epoch 958/1000, Train Loss: 1.1623, Val Loss: 1.6657, Learning rate: 0.000001
# Epoch 959/1000, Train Loss: 1.1605, Val Loss: 1.6658, Learning rate: 0.000001
# Epoch 960/1000, Train Loss: 1.1620, Val Loss: 1.6658, Learning rate: 0.000001
# Epoch 961/1000, Train Loss: 1.1667, Val Loss: 1.6657, Learning rate: 0.000001
# Epoch 962/1000, Train Loss: 1.1663, Val Loss: 1.6658, Learning rate: 0.000001
# Epoch 963/1000, Train Loss: 1.1636, Val Loss: 1.6658, Learning rate: 0.000001
# Epoch 964/1000, Train Loss: 1.1569, Val Loss: 1.6657, Learning rate: 0.000001
# Epoch 965/1000, Train Loss: 1.1650, Val Loss: 1.6658, Learning rate: 0.000001
# Epoch 966/1000, Train Loss: 1.1582, Val Loss: 1.6659, Learning rate: 0.000001
# Epoch 967/1000, Train Loss: 1.1616, Val Loss: 1.6659, Learning rate: 0.000001
# Epoch 968/1000, Train Loss: 1.1646, Val Loss: 1.6658, Learning rate: 0.000001
# Epoch 969/1000, Train Loss: 1.1658, Val Loss: 1.6658, Learning rate: 0.000001
# Epoch 970/1000, Train Loss: 1.1585, Val Loss: 1.6658, Learning rate: 0.000001
# Epoch 971/1000, Train Loss: 1.1632, Val Loss: 1.6658, Learning rate: 0.000001
# Epoch 972/1000, Train Loss: 1.1661, Val Loss: 1.6659, Learning rate: 0.000001
# Epoch 973/1000, Train Loss: 1.1627, Val Loss: 1.6659, Learning rate: 0.000001
# Epoch 974/1000, Train Loss: 1.1613, Val Loss: 1.6659, Learning rate: 0.000001
# Epoch 975/1000, Train Loss: 1.1628, Val Loss: 1.6660, Learning rate: 0.000001
# Epoch 976/1000, Train Loss: 1.1631, Val Loss: 1.6660, Learning rate: 0.000001
# Epoch 977/1000, Train Loss: 1.1607, Val Loss: 1.6659, Learning rate: 0.000001
# Epoch 978/1000, Train Loss: 1.1641, Val Loss: 1.6659, Learning rate: 0.000001
# Epoch 979/1000, Train Loss: 1.1615, Val Loss: 1.6660, Learning rate: 0.000001
# Epoch 980/1000, Train Loss: 1.1641, Val Loss: 1.6661, Learning rate: 0.000001
# Epoch 981/1000, Train Loss: 1.1615, Val Loss: 1.6661, Learning rate: 0.000001
# Epoch 982/1000, Train Loss: 1.1645, Val Loss: 1.6660, Learning rate: 0.000001
# Epoch 983/1000, Train Loss: 1.1635, Val Loss: 1.6661, Learning rate: 0.000001
# Epoch 984/1000, Train Loss: 1.1545, Val Loss: 1.6660, Learning rate: 0.000001
# Epoch 985/1000, Train Loss: 1.1635, Val Loss: 1.6661, Learning rate: 0.000001
# Epoch 986/1000, Train Loss: 1.1634, Val Loss: 1.6660, Learning rate: 0.000001
# Epoch 987/1000, Train Loss: 1.1662, Val Loss: 1.6660, Learning rate: 0.000001
# Epoch 988/1000, Train Loss: 1.1678, Val Loss: 1.6660, Learning rate: 0.000001
# Epoch 989/1000, Train Loss: 1.1634, Val Loss: 1.6660, Learning rate: 0.000001
# Epoch 990/1000, Train Loss: 1.1672, Val Loss: 1.6661, Learning rate: 0.000001
# Epoch 991/1000, Train Loss: 1.1650, Val Loss: 1.6661, Learning rate: 0.000001
# Epoch 992/1000, Train Loss: 1.1614, Val Loss: 1.6661, Learning rate: 0.000001
# Epoch 993/1000, Train Loss: 1.1568, Val Loss: 1.6661, Learning rate: 0.000001
# Epoch 994/1000, Train Loss: 1.1645, Val Loss: 1.6662, Learning rate: 0.000001
# Epoch 995/1000, Train Loss: 1.1584, Val Loss: 1.6661, Learning rate: 0.000001
# Epoch 996/1000, Train Loss: 1.1624, Val Loss: 1.6662, Learning rate: 0.000001
# Epoch 997/1000, Train Loss: 1.1605, Val Loss: 1.6662, Learning rate: 0.000001
# Epoch 998/1000, Train Loss: 1.1612, Val Loss: 1.6662, Learning rate: 0.000001
# Epoch 999/1000, Train Loss: 1.1647, Val Loss: 1.6662, Learning rate: 0.000001
# Epoch 1000/1000, Train Loss: 1.1669, Val Loss: 1.6663, Learning rate: 0.000001
# RandomAgent score: 0.87
# Minimax draw rate: 0.82

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>learning_rate</td><td>█████████████▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>minimax_draw_rate</td><td>▁█▇████▇▇█▇▇▆▆▆▇▆▇▇▆▇</td></tr><tr><td>minimax_loss_rate</td><td>█▁▂▁▁▁▁▂▂▁▂▂▃▃▃▂▃▂▂▃▂</td></tr><tr><td>minimax_score</td><td>▁█▇████▇▇█▇▇▆▆▆▇▆▇▇▆▇</td></tr><tr><td>minimax_win_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>random_draw_rate</td><td>▇▂▁▄▆▅▄▇█▃▅▂▄▇▇▇▇▅▅▇▄</td></tr><tr><td>random_loss_rate</td><td>█▁▁▁▁▁▁▂▁▁▂▂▂▂▁▁▁▂▁▂▂</td></tr><tr><td>random_score</td><td>▁███▇██▇▇█▇▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>random_win_rate</td><td>▁██▇▇▇▇▆▆█▇▇▇▆▆▆▆▇▇▆▇</td></tr><tr><td>train_loss</td><td>█▅▆▄▅▄▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_policy_loss</td><td>█▅▄▄▄▃▃▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_value_loss</td><td>▇▅▃▆▇▆▃▄▇█▅▆▇▂▄▆▅▅▂▄▇▆▁▅▆▂▅▅▄▆▃▄▄▃▃▃▇▅▅▅</td></tr><tr><td>val_loss</td><td>▆▃▃▂▁▁▂▁▁▂▁▃▄▄▅▄▄▅▄▄▆▆▆▆▆▇▇▇▇▇██████████</td></tr><tr><td>val_policy_loss</td><td>▃▁▁▁▂▁▁▁▂▂▂▂▅▅▅▄▄▄▅▆▆▆▇▇▇▇▇▇████████████</td></tr><tr><td>val_value_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>999</td></tr><tr><td>learning_rate</td><td>0.0</td></tr><tr><td>minimax_draw_rate</td><td>0.82</td></tr><tr><td>minimax_loss_rate</td><td>0.18</td></tr><tr><td>minimax_score</td><td>-0.18</td></tr><tr><td>minimax_win_rate</td><td>0</td></tr><tr><td>random_draw_rate</td><td>0.07</td></tr><tr><td>random_loss_rate</td><td>0.03</td></tr><tr><td>random_score</td><td>0.87</td></tr><tr><td>random_win_rate</td><td>0.9</td></tr><tr><td>train_loss</td><td>1.16688</td></tr><tr><td>train_policy_loss</td><td>0.41234</td></tr><tr><td>train_value_loss</td><td>0.75453</td></tr><tr><td>val_loss</td><td>1.66625</td></tr><tr><td>val_policy_loss</td><td>0.89864</td></tr><tr><td>val_value_loss</td><td>0.76761</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">deep-silence-206</strong> at: <a href='https://wandb.ai/eigenway/AlphaZero-TicTacToe/runs/xnyixmrz' target="_blank">https://wandb.ai/eigenway/AlphaZero-TicTacToe/runs/xnyixmrz</a><br> View project at: <a href='https://wandb.ai/eigenway/AlphaZero-TicTacToe' target="_blank">https://wandb.ai/eigenway/AlphaZero-TicTacToe</a><br>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250307_073948-xnyixmrz/logs</code>
